# %% [markdown]
# # 목차
# 1. 필요한 라이브러리 임포트 및 설정
# 2. 슬라이딩 윈도우 함수 정의
# 3. 특성 추출 함수 정의
# 4. 데이터 증강 함수 정의
# 5. MHealth 데이터 로드 및 전처리
# - 5.1 데이터 로드
# - 5.2 데이터 결합
# - 5.3 슬라이딩 윈도우 적용 및 특성 추출
#
# 6. MergeData.csv 데이터 로드 및 전처리
# - 6.1 데이터 로드 및 슬라이딩 윈도우 적용
# - 6.2 데이터 결합
#
# 7. 레이블이 있는 데이터와 없는 데이터
# - 7.1 데이터 결합
# - 7.2 데이터 증강 및 스케일링
#
# 8. 데이터셋 분할 및 시퀀스 생성
# - 8.1 레이블이 있는 데이터와 없는 데이터 분리
# - 8.2 학습 및 검증 데이터 분할
# - 8.3 시퀀스 생성
#
# 9. 데이터셋 및 데이터로더 생성
# 10. CNN-LSTM 모델 정의
# 11. 하이퍼파라미터 튜닝
# - 11.1 Objective 함수 정의
# - 11.2 스터디 객체 생성 및 최적화 수행
#
# 12. 모델 학습
# 13. 모델 평가 및 시각화
# 14. MergeData.csv 데이터에 대한 예측 및 레이블 추가
# - 14.1 MergeData.csv 데이터 예측
# - 14.2 예측된 레이블 추가 및 저장
# - 14.3 예측 결과 시각화
#
# 15. 마무리

# %% [markdown]
# # 1. 필요한 라이브러리 임포트 및 설정

# %%
import os
import glob
import numpy as np
import pandas as pd
from scipy import stats
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm  # 진행 상황 표시

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

import pywt
import optuna  # 하이퍼파라미터 튜닝을 위한 라이브러리

import warnings
import logging

warnings.filterwarnings('ignore')  # 경고 메시지 무시

# 로깅 설정
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s',
                    handlers=[
                        logging.FileHandler("training.log"),
                        logging.StreamHandler()
                    ])
logger = logging.getLogger()

# GPU 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
logger.info(f"사용 중인 디바이스: {device}")
if device.type == 'cuda':
    logger.info(f"GPU 이름: {torch.cuda.get_device_name(0)}")
# Out:
# 2024-10-18 15:03:26,798 - INFO - 사용 중인 디바이스: cuda
# 2024-10-18 15:03:26,805 - INFO - GPU 이름: NVIDIA GeForce GTX 1650

# %% [markdown]
# # 2. 슬라이딩 윈도우 함수 정의

# %%
def sliding_window(data, window_size, step_size):
    """
    슬라이딩 윈도우를 적용하여 데이터를 윈도우로 분할합니다.

    Parameters:
        data (numpy array): 입력 데이터 (samples, channels).
        window_size (int): 윈도우 크기.
        step_size (int): 윈도우 이동 크기.

    Returns:
        numpy array: 윈도우로 분할된 데이터 (num_windows, window_size, channels).
    """
    
    num_samples = data.shape[0]

    if num_samples < window_size:
        return np.array([])  # 빈 배열 반환

    windows = []
    
    for start in range(0, num_samples - window_size + 1, step_size):
        end = start + window_size
        window = data[start:end, :]
        windows.append(window)
        
    return np.array(windows)

# %% [markdown]
# # 3. 특성 추출 함수 정의

# %%
def extract_features(windows):
    """
    각 윈도우에 대해 특성을 추출합니다.

    Parameters:
        windows (numpy array): 윈도우로 분할된 데이터 (num_windows, window_size, channels).

    Returns:
        numpy array: 추출된 특성 (num_windows, num_features).
    """
    
    features = []

    logger.info("Extracting features from windows...")
    
    for window in tqdm(windows, desc="Extracting Features"):
        window_features = []

        if window.ndim == 1:
            window = window[:, np.newaxis]

        num_channels = window.shape[1]

        for channel in range(num_channels):
            signal = window[:, channel]

            # 기본 통계량
            mean = np.mean(signal)
            std = np.std(signal)
            skewness = stats.skew(signal)
            kurtosis = stats.kurtosis(signal)
            rms = np.sqrt(np.mean(signal**2))

            # FFT
            fft_coeffs = np.fft.rfft(signal)
            fft_mean = np.mean(np.abs(fft_coeffs))
            fft_std = np.std(np.abs(fft_coeffs))

            # 웨이블릿 변환 후 에너지
            coeffs = pywt.wavedec(signal, 'db1', level=3)
            energy = sum([np.sum(c**2) for c in coeffs])

            # 특성 벡터에 추가
            window_features.extend([mean, std, skewness, kurtosis, rms, fft_mean, fft_std, energy])

        features.append(window_features)
    return np.array(features)

# %% [markdown]
# # 4. 데이터 증강 함수 정의

# %%
def augment_data(X, y):
    """
    데이터 증강을 위해 다양한 기법을 적용합니다.

    Parameters:
        X (numpy array): 입력 데이터.
        y (numpy array): 레이블.

    Returns:
        tuple: 증강된 데이터와 레이블.
    """
    
    # 가우시안 노이즈 추가
    noise = np.random.normal(0, 0.01, X.shape)
    X_noise = X + noise

    # 시프트 (Shift) 증강
    shift = np.random.randint(-5, 5, size=X.shape)
    X_shift = X + shift

    # 스케일링 (Scaling) 증강
    scaling_factor = np.random.uniform(0.9, 1.1, size=(X.shape[0], X.shape[1]))
    X_scaled = X * scaling_factor

    # 증강된 데이터 결합
    X_augmented = np.vstack((X_noise, X_shift, X_scaled))
    y_augmented = np.hstack((y, y, y))

    return X_augmented, y_augmented

# %% [markdown]
# # 5. MHealth 데이터 로드 및 전처리
# ***
# ## 5.1 데이터 로드

# %%
# 데이터 파일 경로 설정 (실제 데이터 경로로 수정하세요)
data_files = glob.glob('C:/AI/data/MHEALTHDATASET/mHealth_subject*.log')  # 실제 경로로 변경

# 데이터와 레이블을 저장할 리스트 초기화
X_list = []
y_list = []

logger.info("Loading MHealth dataset...")
for file in tqdm(data_files, desc="Loading MHealth Files"):
    data = pd.read_csv(file, sep='\s+', header=None)
    logger.info(f"파일명: {file}")
    logger.info(f"data.shape: {data.shape}")

    # 데이터의 열 수가 24개인지 확인
    if data.shape[1] != 24:
        logger.warning(f"데이터의 열 수가 24가 아닙니다. 파일을 확인하세요: {file}")
        continue  # 다음 파일로 넘어감

    # 우측 하완 센서의 자이로스코프 데이터 추출 (열 18~20)
    right_arm_gyro = data.iloc[:, 17:20].values   # 열 18~20 (Python 인덱스는 0부터 시작)
    logger.info(f"right_arm_gyro.shape: {right_arm_gyro.shape}")

    # 레이블 추출 (열 24)
    labels = data.iloc[:, 23].values
    logger.info(f"labels.shape: {labels.shape}")

    # null 클래스(레이블 0)는 제외
    valid_indices = labels != 0
    sensor_data = right_arm_gyro[valid_indices, :]  # 모든 열 선택
    labels = labels[valid_indices]

    # 데이터와 레이블 저장
    X_list.append(sensor_data)
    y_list.append(labels)

logger.info("MHealth 데이터 로드 완료.")
# Out:
# 2024-10-18 15:03:26,938 - INFO - Loading MHealth dataset...
# Loading MHealth Files:   0%|                                  | 0/10 [00:00<?, ?it/s]2024-10-18 15:03:28,008 - INFO - 파일명: C:/AI/data/MHEALTHDATASET\mHealth_subject1.log
# 2024-10-18 15:03:28,009 - INFO - data.shape: (161280, 24)
# 2024-10-18 15:03:28,012 - INFO - right_arm_gyro.shape: (161280, 3)
# 2024-10-18 15:03:28,013 - INFO - labels.shape: (161280,)
# Loading MHealth Files:  10%|██▌                       | 1/10 [00:01<00:09,  1.07s/it]2024-10-18 15:03:28,663 - INFO - 파일명: C:/AI/data/MHEALTHDATASET\mHealth_subject10.log
# 2024-10-18 15:03:28,664 - INFO - data.shape: (98304, 24)
# 2024-10-18 15:03:28,666 - INFO - right_arm_gyro.shape: (98304, 3)
# 2024-10-18 15:03:28,667 - INFO - labels.shape: (98304,)
# Loading MHealth Files:  20%|█████▏                    | 2/10 [00:01<00:06,  1.21it/s]2024-10-18 15:03:29,583 - INFO - 파일명: C:/AI/data/MHEALTHDATASET\mHealth_subject2.log
# 2024-10-18 15:03:29,584 - INFO - data.shape: (130561, 24)
# 2024-10-18 15:03:29,586 - INFO - right_arm_gyro.shape: (130561, 3)
# 2024-10-18 15:03:29,587 - INFO - labels.shape: (130561,)
# Loading MHealth Files:  30%|███████▊                  | 3/10 [00:02<00:06,  1.15it/s]2024-10-18 15:03:30,414 - INFO - 파일명: C:/AI/data/MHEALTHDATASET\mHealth_subject3.log
# 2024-10-18 15:03:30,415 - INFO - data.shape: (122112, 24)
# 2024-10-18 15:03:30,417 - INFO - right_arm_gyro.shape: (122112, 3)
# 2024-10-18 15:03:30,418 - INFO - labels.shape: (122112,)
# Loading MHealth Files:  40%|██████████▍               | 4/10 [00:03<00:05,  1.17it/s]2024-10-18 15:03:31,184 - INFO - 파일명: C:/AI/data/MHEALTHDATASET\mHealth_subject4.log
# 2024-10-18 15:03:31,186 - INFO - data.shape: (116736, 24)
# 2024-10-18 15:03:31,188 - INFO - right_arm_gyro.shape: (116736, 3)
# 2024-10-18 15:03:31,189 - INFO - labels.shape: (116736,)
# Loading MHealth Files:  50%|█████████████             | 5/10 [00:04<00:04,  1.21it/s]2024-10-18 15:03:31,984 - INFO - 파일명: C:/AI/data/MHEALTHDATASET\mHealth_subject5.log
# 2024-10-18 15:03:31,985 - INFO - data.shape: (119808, 24)
# 2024-10-18 15:03:31,987 - INFO - right_arm_gyro.shape: (119808, 3)
# 2024-10-18 15:03:31,988 - INFO - labels.shape: (119808,)
# Loading MHealth Files:  60%|███████████████▌          | 6/10 [00:05<00:03,  1.23it/s]2024-10-18 15:03:32,652 - INFO - 파일명: C:/AI/data/MHEALTHDATASET\mHealth_subject6.log
# 2024-10-18 15:03:32,653 - INFO - data.shape: (98304, 24)
# 2024-10-18 15:03:32,655 - INFO - right_arm_gyro.shape: (98304, 3)
# 2024-10-18 15:03:32,655 - INFO - labels.shape: (98304,)
# Loading MHealth Files:  70%|██████████████████▏       | 7/10 [00:05<00:02,  1.30it/s]2024-10-18 15:03:33,340 - INFO - 파일명: C:/AI/data/MHEALTHDATASET\mHealth_subject7.log
# 2024-10-18 15:03:33,342 - INFO - data.shape: (104448, 24)
# 2024-10-18 15:03:33,343 - INFO - right_arm_gyro.shape: (104448, 3)
# 2024-10-18 15:03:33,344 - INFO - labels.shape: (104448,)
# Loading MHealth Files:  80%|████████████████████▊     | 8/10 [00:06<00:01,  1.35it/s]2024-10-18 15:03:34,181 - INFO - 파일명: C:/AI/data/MHEALTHDATASET\mHealth_subject8.log
# 2024-10-18 15:03:34,182 - INFO - data.shape: (129024, 24)
# 2024-10-18 15:03:34,184 - INFO - right_arm_gyro.shape: (129024, 3)
# 2024-10-18 15:03:34,185 - INFO - labels.shape: (129024,)
# Loading MHealth Files:  90%|███████████████████████▍  | 9/10 [00:07<00:00,  1.29it/s]2024-10-18 15:03:35,095 - INFO - 파일명: C:/AI/data/MHEALTHDATASET\mHealth_subject9.log
# 2024-10-18 15:03:35,096 - INFO - data.shape: (135168, 24)
# 2024-10-18 15:03:35,098 - INFO - right_arm_gyro.shape: (135168, 3)
# 2024-10-18 15:03:35,098 - INFO - labels.shape: (135168,)
# Loading MHealth Files: 100%|█████████████████████████| 10/10 [00:08<00:00,  1.23it/s]
# 2024-10-18 15:03:35,102 - INFO - MHealth 데이터 로드 완료.

# %% [markdown]
# # 5.2 데이터 결합

# %%
# 리스트를 배열로 변환
X_raw_mhealth = np.vstack(X_list)
y_raw_mhealth = np.hstack(y_list)

# 레이블을 0부터 시작하도록 조정
y_raw_mhealth = y_raw_mhealth - 1  # 레이블이 1부터 시작하므로 0부터 시작하도록 조정

logger.info(f"전체 MHealth 데이터 크기: {X_raw_mhealth.shape}")
logger.info(f"전체 MHealth 레이블 크기: {y_raw_mhealth.shape}")
# Out:
# 2024-10-18 15:03:35,117 - INFO - 전체 MHealth 데이터 크기: (343195, 3)
# 2024-10-18 15:03:35,119 - INFO - 전체 MHealth 레이블 크기: (343195,)

# %% [markdown]
# # 5.3 슬라이딩 윈도우 적용 및 특성 추출

# %%
# 윈도우 설정
window_size = 128  # 샘플 수에 따라 조정 가능
step_size = 64

logger.info("Applying sliding window to MHealth data...")
# 슬라이딩 윈도우 적용
windows = sliding_window(X_raw_mhealth, window_size, step_size)

# 레이블 슬라이딩 윈도우 적용 (다수결을 통해 레이블 결정)
labels_windows = sliding_window(y_raw_mhealth.reshape(-1, 1), window_size, step_size)

logger.info("Assigning labels to each window based on majority vote...")
window_labels = [np.bincount(label_window.flatten().astype(int)).argmax() for label_window in tqdm(labels_windows, desc="Assigning Window Labels")]

# 특성 추출
logger.info("Extracting features from MHealth windows...")
X_features_mhealth = extract_features(windows)
y_labels_mhealth = np.array(window_labels)

logger.info(f"MHealth 데이터 특성 크기: {X_features_mhealth.shape}")
logger.info(f"MHealth 레이블 크기: {y_labels_mhealth.shape}")
# Out:
# 2024-10-18 15:03:35,146 - INFO - Applying sliding window to MHealth data...
# 2024-10-18 15:03:35,160 - INFO - Assigning labels to each window based on majority vote...
# Assigning Window Labels: 100%|███████████████| 5361/5361 [00:00<00:00, 297760.26it/s]
# 2024-10-18 15:03:35,182 - INFO - Extracting features from MHealth windows...
# 2024-10-18 15:03:35,182 - INFO - Extracting features from windows...
# Extracting Features: 100%|██████████████████████| 5361/5361 [00:17<00:00, 298.41it/s]
# 2024-10-18 15:03:53,159 - INFO - MHealth 데이터 특성 크기: (5361, 24)
# 2024-10-18 15:03:53,160 - INFO - MHealth 레이블 크기: (5361,)

# %% [markdown]
# # 6. MergeData.csv 데이터 로드 및 전처리
# ***
# ## 6.1 데이터 로드 및 슬라이딩 윈도우 적용

# %%
# MergeData.csv 파일 경로 설정
merge_data_path = 'C:/AI/data/MergeData.csv'

# 청크 크기 설정 (메모리 용량에 따라 조정)
chunk_size = 100000  # 한 번에 읽어올 행의 수

# 데이터와 레이블을 저장할 리스트 초기화
X_list_merge = []

# 컬럼 이름 지정
column_names = ['VitalDate',
                'WorkDate',
                'UserCode',
                'HeartBeat',
                'Temperature',
                'OutsideTemperature',
                'Latitude',
                'Longitude',
                'X',
                'Y',
                'Z']

logger.info("Loading and processing MergeData.csv...")
# 데이터 로드 및 전처리
reader = pd.read_csv(merge_data_path,
                     chunksize=chunk_size,
                     names=column_names,
                     header=0)

for chunk in tqdm(reader, desc='Processing MergeData Chunks'):
    # 자이로스코프 데이터 추출 (X, Y, Z 컬럼)
    gyro_data = chunk[['X', 'Y', 'Z']].values

    if gyro_data.shape[0] < window_size:
        continue  # 데이터 길이가 윈도우 크기보다 작으면 건너뜀

    # 슬라이딩 윈도우 적용
    windows = sliding_window(gyro_data,
                             window_size=window_size,
                             step_size=step_size)

    if windows.size == 0:
        continue

    # 특성 추출
    features = extract_features(windows)

    # 데이터 저장
    X_list_merge.append(features)

logger.info("MergeData.csv 데이터 처리 완료.")
# Out:
# 2024-10-18 15:03:53,174 - INFO - Loading and processing MergeData.csv...
# Processing MergeData Chunks: 0it [00:00, ?it/s]2024-10-18 15:03:53,313 - INFO - Extracting features from windows...
#
# Extracting Features:   0%|                                  | 0/1561 [00:00<?, ?it/s]
# Extracting Features:   2%|▍                       | 31/1561 [00:00<00:04, 309.98it/s]
# Extracting Features:   4%|▉                       | 62/1561 [00:00<00:04, 306.31it/s]
# Extracting Features:   6%|█▍                      | 93/1561 [00:00<00:04, 305.28it/s]
# Extracting Features:   8%|█▊                     | 124/1561 [00:00<00:04, 304.74it/s]
# Extracting Features:  10%|██▎                    | 155/1561 [00:00<00:04, 305.52it/s]
# Extracting Features:  12%|██▊                    | 187/1561 [00:00<00:04, 308.33it/s]
# Extracting Features:  14%|███▏                   | 218/1561 [00:00<00:04, 303.95it/s]
# Extracting Features:  16%|███▋                   | 249/1561 [00:00<00:04, 298.62it/s]
# Extracting Features:  18%|████▏                  | 280/1561 [00:00<00:04, 299.66it/s]
# Extracting Features:  20%|████▌                  | 311/1561 [00:01<00:04, 300.96it/s]
# Extracting Features:  22%|█████                  | 342/1561 [00:01<00:04, 301.85it/s]
# Extracting Features:  24%|█████▍                 | 373/1561 [00:01<00:04, 293.56it/s]
# Extracting Features:  26%|█████▉                 | 404/1561 [00:01<00:03, 298.19it/s]
# Extracting Features:  28%|██████▍                | 434/1561 [00:01<00:03, 297.88it/s]
# Extracting Features:  30%|██████▊                | 464/1561 [00:01<00:03, 295.88it/s]
# Extracting Features:  32%|███████▎               | 494/1561 [00:01<00:03, 294.49it/s]
# Extracting Features:  34%|███████▋               | 525/1561 [00:01<00:03, 297.31it/s]
# Extracting Features:  36%|████████▏              | 556/1561 [00:01<00:03, 298.41it/s]
# Extracting Features:  38%|████████▋              | 587/1561 [00:01<00:03, 300.93it/s]
# Extracting Features:  40%|█████████              | 618/1561 [00:02<00:03, 301.83it/s]
# Extracting Features:  42%|█████████▌             | 649/1561 [00:02<00:03, 299.79it/s]
# Extracting Features:  43%|██████████             | 679/1561 [00:02<00:03, 292.97it/s]
# Extracting Features:  45%|██████████▍            | 709/1561 [00:02<00:02, 286.70it/s]
# Extracting Features:  47%|██████████▉            | 739/1561 [00:02<00:02, 288.84it/s]
# Extracting Features:  49%|███████████▎           | 769/1561 [00:02<00:02, 290.42it/s]
# Extracting Features:  51%|███████████▊           | 800/1561 [00:02<00:02, 293.55it/s]
# Extracting Features:  53%|████████████▏          | 831/1561 [00:02<00:02, 297.50it/s]
# Extracting Features:  55%|████████████▋          | 862/1561 [00:02<00:02, 300.30it/s]
# Extracting Features:  57%|█████████████▏         | 893/1561 [00:03<00:02, 290.94it/s]
# Extracting Features:  59%|█████████████▌         | 923/1561 [00:03<00:02, 288.90it/s]
# Extracting Features:  61%|██████████████         | 952/1561 [00:03<00:02, 283.50it/s]
# Extracting Features:  63%|██████████████▍        | 981/1561 [00:03<00:02, 282.90it/s]
# Extracting Features:  65%|██████████████▏       | 1011/1561 [00:03<00:01, 285.37it/s]
# Extracting Features:  67%|██████████████▋       | 1042/1561 [00:03<00:01, 291.71it/s]
# Extracting Features:  69%|███████████████       | 1073/1561 [00:03<00:01, 296.20it/s]
# Extracting Features:  71%|███████████████▌      | 1103/1561 [00:03<00:01, 297.29it/s]
# Extracting Features:  73%|███████████████▉      | 1133/1561 [00:03<00:01, 293.75it/s]
# Extracting Features:  75%|████████████████▍     | 1163/1561 [00:03<00:01, 288.77it/s]
# Extracting Features:  76%|████████████████▊     | 1194/1561 [00:04<00:01, 292.42it/s]
# Extracting Features:  78%|█████████████████▎    | 1225/1561 [00:04<00:01, 294.97it/s]
# Extracting Features:  80%|█████████████████▋    | 1255/1561 [00:04<00:01, 295.60it/s]
# Extracting Features:  82%|██████████████████    | 1285/1561 [00:04<00:00, 295.16it/s]
# Extracting Features:  84%|██████████████████▌   | 1316/1561 [00:04<00:00, 297.75it/s]
# Extracting Features:  86%|██████████████████▉   | 1346/1561 [00:04<00:00, 296.64it/s]
# Extracting Features:  88%|███████████████████▍  | 1376/1561 [00:04<00:00, 294.18it/s]
# Extracting Features:  90%|███████████████████▊  | 1406/1561 [00:04<00:00, 291.63it/s]
# Extracting Features:  92%|████████████████████▎ | 1437/1561 [00:04<00:00, 296.12it/s]
# Extracting Features:  94%|████████████████████▋ | 1468/1561 [00:04<00:00, 296.74it/s]
# Extracting Features:  96%|█████████████████████ | 1498/1561 [00:05<00:00, 297.67it/s]
# Extracting Features:  98%|█████████████████████▌| 1528/1561 [00:05<00:00, 293.71it/s]
# Extracting Features: 100%|██████████████████████| 1561/1561 [00:05<00:00, 295.48it/s]
# Processing MergeData Chunks: 1it [00:05,  5.41s/it]2024-10-18 15:03:58,716 - INFO - Extracting features from windows...
#
# Extracting Features:   0%|                                  | 0/1561 [00:00<?, ?it/s]
# Extracting Features:   2%|▍                       | 31/1561 [00:00<00:04, 309.90it/s]
# Extracting Features:   4%|▉                       | 62/1561 [00:00<00:04, 308.15it/s]
# Extracting Features:   6%|█▍                      | 93/1561 [00:00<00:04, 307.59it/s]
# Extracting Features:   8%|█▊                     | 124/1561 [00:00<00:04, 303.76it/s]
# Extracting Features:  10%|██▎                    | 155/1561 [00:00<00:04, 298.57it/s]
# Extracting Features:  12%|██▋                    | 186/1561 [00:00<00:04, 300.35it/s]
# Extracting Features:  14%|███▏                   | 217/1561 [00:00<00:04, 300.58it/s]
# Extracting Features:  16%|███▋                   | 248/1561 [00:00<00:04, 299.40it/s]
# Extracting Features:  18%|████                   | 278/1561 [00:00<00:04, 298.67it/s]
# Extracting Features:  20%|████▌                  | 308/1561 [00:01<00:04, 268.93it/s]
# Extracting Features:  22%|████▉                  | 336/1561 [00:01<00:04, 271.59it/s]
# Extracting Features:  24%|█████▍                 | 367/1561 [00:01<00:04, 279.36it/s]
# Extracting Features:  25%|█████▊                 | 397/1561 [00:01<00:04, 283.66it/s]
# Extracting Features:  27%|██████▎                | 427/1561 [00:01<00:03, 287.59it/s]
# Extracting Features:  29%|██████▋                | 458/1561 [00:01<00:03, 291.56it/s]
# Extracting Features:  31%|███████▏               | 489/1561 [00:01<00:03, 293.55it/s]
# Extracting Features:  33%|███████▋               | 519/1561 [00:01<00:03, 269.43it/s]
# Extracting Features:  35%|████████               | 549/1561 [00:01<00:03, 275.58it/s]
# Extracting Features:  37%|████████▌              | 577/1561 [00:02<00:03, 276.66it/s]
# Extracting Features:  39%|████████▉              | 606/1561 [00:02<00:03, 280.01it/s]
# Extracting Features:  41%|█████████▎             | 636/1561 [00:02<00:03, 284.46it/s]
# Extracting Features:  43%|█████████▊             | 666/1561 [00:02<00:03, 288.98it/s]
# Extracting Features:  45%|██████████▎            | 698/1561 [00:02<00:02, 295.52it/s]
# Extracting Features:  47%|██████████▋            | 729/1561 [00:02<00:02, 298.00it/s]
# Extracting Features:  49%|███████████▏           | 760/1561 [00:02<00:02, 298.92it/s]
# Extracting Features:  51%|███████████▋           | 790/1561 [00:02<00:02, 298.36it/s]
# Extracting Features:  53%|████████████           | 820/1561 [00:02<00:02, 292.76it/s]
# Extracting Features:  54%|████████████▌          | 850/1561 [00:02<00:02, 294.02it/s]
# Extracting Features:  56%|████████████▉          | 881/1561 [00:03<00:02, 296.12it/s]
# Extracting Features:  58%|█████████████▍         | 911/1561 [00:03<00:02, 295.51it/s]
# Extracting Features:  60%|█████████████▊         | 941/1561 [00:03<00:02, 295.96it/s]
# Extracting Features:  62%|██████████████▎        | 972/1561 [00:03<00:01, 296.63it/s]
# Extracting Features:  64%|██████████████▏       | 1003/1561 [00:03<00:01, 299.69it/s]
# Extracting Features:  66%|██████████████▌       | 1033/1561 [00:03<00:01, 298.89it/s]
# Extracting Features:  68%|██████████████▉       | 1063/1561 [00:03<00:01, 298.31it/s]
# Extracting Features:  70%|███████████████▍      | 1094/1561 [00:03<00:01, 300.91it/s]
# Extracting Features:  72%|███████████████▊      | 1125/1561 [00:03<00:01, 300.91it/s]
# Extracting Features:  74%|████████████████▎     | 1156/1561 [00:03<00:01, 300.92it/s]
# Extracting Features:  76%|████████████████▋     | 1187/1561 [00:04<00:01, 299.21it/s]
# Extracting Features:  78%|█████████████████▏    | 1217/1561 [00:04<00:01, 291.66it/s]
# Extracting Features:  80%|█████████████████▌    | 1247/1561 [00:04<00:01, 289.29it/s]
# Extracting Features:  82%|█████████████████▉    | 1276/1561 [00:04<00:00, 289.48it/s]
# Extracting Features:  84%|██████████████████▍   | 1307/1561 [00:04<00:00, 293.76it/s]
# Extracting Features:  86%|██████████████████▊   | 1338/1561 [00:04<00:00, 295.95it/s]
# Extracting Features:  88%|███████████████████▎  | 1368/1561 [00:04<00:00, 297.14it/s]
# Extracting Features:  90%|███████████████████▋  | 1398/1561 [00:04<00:00, 283.73it/s]
# Extracting Features:  91%|████████████████████  | 1427/1561 [00:04<00:00, 279.12it/s]
# Extracting Features:  93%|████████████████████▌ | 1457/1561 [00:05<00:00, 283.47it/s]
# Extracting Features:  95%|████████████████████▉ | 1486/1561 [00:05<00:00, 285.33it/s]
# Extracting Features:  97%|█████████████████████▎| 1515/1561 [00:05<00:00, 286.70it/s]
# Extracting Features: 100%|██████████████████████| 1561/1561 [00:05<00:00, 291.39it/s]
# Processing MergeData Chunks: 2it [00:10,  5.45s/it]2024-10-18 15:04:04,194 - INFO - Extracting features from windows...
#
# Extracting Features:   0%|                                  | 0/1561 [00:00<?, ?it/s]
# Extracting Features:   2%|▍                       | 31/1561 [00:00<00:04, 306.85it/s]
# Extracting Features:   4%|▉                       | 62/1561 [00:00<00:04, 301.63it/s]
# Extracting Features:   6%|█▍                      | 93/1561 [00:00<00:04, 304.06it/s]
# Extracting Features:   8%|█▊                     | 124/1561 [00:00<00:04, 301.64it/s]
# Extracting Features:  10%|██▎                    | 155/1561 [00:00<00:04, 301.40it/s]
# Extracting Features:  12%|██▋                    | 186/1561 [00:00<00:04, 303.25it/s]
# Extracting Features:  14%|███▏                   | 217/1561 [00:00<00:04, 302.53it/s]
# Extracting Features:  16%|███▋                   | 248/1561 [00:00<00:04, 301.10it/s]
# Extracting Features:  18%|████                   | 279/1561 [00:00<00:04, 293.57it/s]
# Extracting Features:  20%|████▌                  | 309/1561 [00:01<00:04, 291.85it/s]
# Extracting Features:  22%|█████                  | 340/1561 [00:01<00:04, 295.86it/s]
# Extracting Features:  24%|█████▍                 | 371/1561 [00:01<00:03, 299.16it/s]
# Extracting Features:  26%|█████▉                 | 402/1561 [00:01<00:03, 301.48it/s]
# Extracting Features:  28%|██████▍                | 433/1561 [00:01<00:03, 303.11it/s]
# Extracting Features:  30%|██████▊                | 464/1561 [00:01<00:03, 303.35it/s]
# Extracting Features:  32%|███████▎               | 495/1561 [00:01<00:03, 301.75it/s]
# Extracting Features:  34%|███████▊               | 526/1561 [00:01<00:03, 301.51it/s]
# Extracting Features:  36%|████████▏              | 557/1561 [00:01<00:03, 297.89it/s]
# Extracting Features:  38%|████████▋              | 587/1561 [00:01<00:03, 297.61it/s]
# Extracting Features:  40%|█████████              | 617/1561 [00:02<00:03, 297.44it/s]
# Extracting Features:  41%|█████████▌             | 647/1561 [00:02<00:03, 298.20it/s]
# Extracting Features:  43%|█████████▉             | 677/1561 [00:02<00:02, 295.24it/s]
# Extracting Features:  45%|██████████▍            | 707/1561 [00:02<00:02, 288.99it/s]
# Extracting Features:  47%|██████████▊            | 736/1561 [00:02<00:02, 286.78it/s]
# Extracting Features:  49%|███████████▎           | 767/1561 [00:02<00:02, 291.85it/s]
# Extracting Features:  51%|███████████▋           | 797/1561 [00:02<00:02, 290.80it/s]
# Extracting Features:  53%|████████████▏          | 827/1561 [00:02<00:02, 275.76it/s]
# Extracting Features:  55%|████████████▋          | 857/1561 [00:02<00:02, 280.99it/s]
# Extracting Features:  57%|█████████████          | 888/1561 [00:03<00:02, 286.04it/s]
# Extracting Features:  59%|█████████████▌         | 917/1561 [00:03<00:02, 284.39it/s]
# Extracting Features:  61%|█████████████▉         | 948/1561 [00:03<00:02, 289.57it/s]
# Extracting Features:  63%|██████████████▍        | 978/1561 [00:03<00:01, 292.00it/s]
# Extracting Features:  65%|██████████████▏       | 1008/1561 [00:03<00:01, 290.96it/s]
# Extracting Features:  67%|██████████████▋       | 1039/1561 [00:03<00:01, 294.78it/s]
# Extracting Features:  69%|███████████████       | 1070/1561 [00:03<00:01, 298.37it/s]
# Extracting Features:  70%|███████████████▌      | 1100/1561 [00:03<00:01, 295.29it/s]
# Extracting Features:  72%|███████████████▉      | 1130/1561 [00:03<00:01, 296.65it/s]
# Extracting Features:  74%|████████████████▎     | 1160/1561 [00:03<00:01, 295.89it/s]
# Extracting Features:  76%|████████████████▊     | 1192/1561 [00:04<00:01, 300.35it/s]
# Extracting Features:  78%|█████████████████▏    | 1223/1561 [00:04<00:01, 299.66it/s]
# Extracting Features:  80%|█████████████████▋    | 1254/1561 [00:04<00:01, 300.93it/s]
# Extracting Features:  82%|██████████████████    | 1285/1561 [00:04<00:00, 299.20it/s]
# Extracting Features:  84%|██████████████████▌   | 1315/1561 [00:04<00:00, 299.43it/s]
# Extracting Features:  86%|██████████████████▉   | 1346/1561 [00:04<00:00, 299.90it/s]
# Extracting Features:  88%|███████████████████▍  | 1377/1561 [00:04<00:00, 301.13it/s]
# Extracting Features:  90%|███████████████████▊  | 1408/1561 [00:04<00:00, 301.08it/s]
# Extracting Features:  92%|████████████████████▎ | 1439/1561 [00:04<00:00, 300.14it/s]
# Extracting Features:  94%|████████████████████▋ | 1470/1561 [00:04<00:00, 298.67it/s]
# Extracting Features:  96%|█████████████████████▏| 1500/1561 [00:05<00:00, 297.30it/s]
# Extracting Features:  98%|█████████████████████▌| 1530/1561 [00:05<00:00, 294.63it/s]
# Extracting Features: 100%|██████████████████████| 1561/1561 [00:05<00:00, 295.70it/s]
# Processing MergeData Chunks: 3it [00:16,  5.43s/it]2024-10-18 15:04:09,596 - INFO - Extracting features from windows...
#
# Extracting Features:   0%|                                  | 0/1561 [00:00<?, ?it/s]
# Extracting Features:   2%|▍                       | 30/1561 [00:00<00:05, 298.27it/s]
# Extracting Features:   4%|▉                       | 60/1561 [00:00<00:05, 294.15it/s]
# Extracting Features:   6%|█▍                      | 90/1561 [00:00<00:05, 290.21it/s]
# Extracting Features:   8%|█▊                     | 121/1561 [00:00<00:04, 293.36it/s]
# Extracting Features:  10%|██▏                    | 152/1561 [00:00<00:04, 298.14it/s]
# Extracting Features:  12%|██▋                    | 182/1561 [00:00<00:04, 295.79it/s]
# Extracting Features:  14%|███                    | 212/1561 [00:00<00:04, 292.45it/s]
# Extracting Features:  16%|███▌                   | 243/1561 [00:00<00:04, 296.08it/s]
# Extracting Features:  17%|████                   | 273/1561 [00:00<00:04, 294.56it/s]
# Extracting Features:  19%|████▍                  | 303/1561 [00:01<00:04, 292.67it/s]
# Extracting Features:  21%|████▉                  | 334/1561 [00:01<00:04, 296.96it/s]
# Extracting Features:  23%|█████▍                 | 365/1561 [00:01<00:03, 299.99it/s]
# Extracting Features:  25%|█████▊                 | 396/1561 [00:01<00:03, 297.63it/s]
# Extracting Features:  27%|██████▎                | 426/1561 [00:01<00:03, 294.86it/s]
# Extracting Features:  29%|██████▋                | 456/1561 [00:01<00:03, 291.21it/s]
# Extracting Features:  31%|███████▏               | 487/1561 [00:01<00:03, 294.15it/s]
# Extracting Features:  33%|███████▋               | 518/1561 [00:01<00:03, 297.02it/s]
# Extracting Features:  35%|████████               | 549/1561 [00:01<00:03, 299.07it/s]
# Extracting Features:  37%|████████▌              | 579/1561 [00:01<00:03, 290.79it/s]
# Extracting Features:  39%|████████▉              | 609/1561 [00:02<00:03, 285.53it/s]
# Extracting Features:  41%|█████████▍             | 638/1561 [00:02<00:03, 284.20it/s]
# Extracting Features:  43%|█████████▊             | 668/1561 [00:02<00:03, 287.32it/s]
# Extracting Features:  45%|██████████▎            | 698/1561 [00:02<00:02, 290.98it/s]
# Extracting Features:  47%|██████████▋            | 729/1561 [00:02<00:02, 295.70it/s]
# Extracting Features:  49%|███████████▏           | 761/1561 [00:02<00:02, 299.34it/s]
# Extracting Features:  51%|███████████▋           | 791/1561 [00:02<00:02, 297.78it/s]
# Extracting Features:  53%|████████████           | 821/1561 [00:02<00:02, 295.82it/s]
# Extracting Features:  55%|████████████▌          | 851/1561 [00:02<00:02, 293.60it/s]
# Extracting Features:  56%|████████████▉          | 881/1561 [00:02<00:02, 291.22it/s]
# Extracting Features:  58%|█████████████▍         | 911/1561 [00:03<00:02, 292.94it/s]
# Extracting Features:  60%|█████████████▉         | 942/1561 [00:03<00:02, 297.06it/s]
# Extracting Features:  62%|██████████████▎        | 972/1561 [00:03<00:01, 297.07it/s]
# Extracting Features:  64%|██████████████▏       | 1003/1561 [00:03<00:01, 298.23it/s]
# Extracting Features:  66%|██████████████▌       | 1033/1561 [00:03<00:01, 297.87it/s]
# Extracting Features:  68%|██████████████▉       | 1064/1561 [00:03<00:01, 300.57it/s]
# Extracting Features:  70%|███████████████▍      | 1095/1561 [00:03<00:01, 300.72it/s]
# Extracting Features:  72%|███████████████▊      | 1126/1561 [00:03<00:01, 300.80it/s]
# Extracting Features:  74%|████████████████▎     | 1157/1561 [00:03<00:01, 301.73it/s]
# Extracting Features:  76%|████████████████▋     | 1188/1561 [00:04<00:01, 303.25it/s]
# Extracting Features:  78%|█████████████████▏    | 1219/1561 [00:04<00:01, 304.34it/s]
# Extracting Features:  80%|█████████████████▌    | 1250/1561 [00:04<00:01, 289.72it/s]
# Extracting Features:  82%|██████████████████    | 1280/1561 [00:04<00:00, 287.46it/s]
# Extracting Features:  84%|██████████████████▍   | 1310/1561 [00:04<00:00, 289.95it/s]
# Extracting Features:  86%|██████████████████▉   | 1340/1561 [00:04<00:00, 290.63it/s]
# Extracting Features:  88%|███████████████████▎  | 1371/1561 [00:04<00:00, 294.58it/s]
# Extracting Features:  90%|███████████████████▊  | 1402/1561 [00:04<00:00, 297.35it/s]
# Extracting Features:  92%|████████████████████▏ | 1433/1561 [00:04<00:00, 299.28it/s]
# Extracting Features:  94%|████████████████████▌ | 1463/1561 [00:04<00:00, 297.77it/s]
# Extracting Features:  96%|█████████████████████ | 1493/1561 [00:05<00:00, 297.52it/s]
# Extracting Features:  98%|█████████████████████▍| 1524/1561 [00:05<00:00, 299.44it/s]
# Extracting Features: 100%|██████████████████████| 1561/1561 [00:05<00:00, 295.56it/s]
# Processing MergeData Chunks: 4it [00:21,  5.42s/it]2024-10-18 15:04:14,991 - INFO - Extracting features from windows...
#
# Extracting Features:   0%|                                  | 0/1561 [00:00<?, ?it/s]
# Extracting Features:   2%|▍                       | 31/1561 [00:00<00:04, 306.84it/s]
# Extracting Features:   4%|▉                       | 62/1561 [00:00<00:05, 296.53it/s]
# Extracting Features:   6%|█▍                      | 93/1561 [00:00<00:04, 299.90it/s]
# Extracting Features:   8%|█▊                     | 124/1561 [00:00<00:04, 300.29it/s]
# Extracting Features:  10%|██▎                    | 156/1561 [00:00<00:04, 302.97it/s]
# Extracting Features:  12%|██▊                    | 187/1561 [00:00<00:04, 301.30it/s]
# Extracting Features:  14%|███▏                   | 218/1561 [00:00<00:04, 302.15it/s]
# Extracting Features:  16%|███▋                   | 249/1561 [00:00<00:04, 300.84it/s]
# Extracting Features:  18%|████▏                  | 280/1561 [00:00<00:04, 301.80it/s]
# Extracting Features:  20%|████▌                  | 311/1561 [00:01<00:04, 297.99it/s]
# Extracting Features:  22%|█████                  | 341/1561 [00:01<00:04, 290.62it/s]
# Extracting Features:  24%|█████▍                 | 371/1561 [00:01<00:04, 290.14it/s]
# Extracting Features:  26%|█████▉                 | 401/1561 [00:01<00:04, 285.83it/s]
# Extracting Features:  28%|██████▎                | 430/1561 [00:01<00:04, 281.33it/s]
# Extracting Features:  29%|██████▊                | 459/1561 [00:01<00:03, 279.77it/s]
# Extracting Features:  31%|███████▏               | 488/1561 [00:01<00:03, 280.32it/s]
# Extracting Features:  33%|███████▌               | 517/1561 [00:01<00:03, 281.47it/s]
# Extracting Features:  35%|████████               | 548/1561 [00:01<00:03, 286.46it/s]
# Extracting Features:  37%|████████▌              | 578/1561 [00:01<00:03, 289.59it/s]
# Extracting Features:  39%|████████▉              | 608/1561 [00:02<00:03, 290.92it/s]
# Extracting Features:  41%|█████████▍             | 638/1561 [00:02<00:03, 291.90it/s]
# Extracting Features:  43%|█████████▊             | 668/1561 [00:02<00:03, 291.70it/s]
# Extracting Features:  45%|██████████▎            | 698/1561 [00:02<00:02, 293.26it/s]
# Extracting Features:  47%|██████████▋            | 728/1561 [00:02<00:02, 293.54it/s]
# Extracting Features:  49%|███████████▏           | 758/1561 [00:02<00:02, 273.18it/s]
# Extracting Features:  50%|███████████▌           | 786/1561 [00:02<00:02, 272.80it/s]
# Extracting Features:  52%|███████████▉           | 814/1561 [00:02<00:02, 274.04it/s]
# Extracting Features:  54%|████████████▍          | 842/1561 [00:02<00:02, 274.97it/s]
# Extracting Features:  56%|████████████▊          | 872/1561 [00:03<00:02, 280.62it/s]
# Extracting Features:  58%|█████████████▎         | 903/1561 [00:03<00:02, 286.72it/s]
# Extracting Features:  60%|█████████████▋         | 933/1561 [00:03<00:02, 288.09it/s]
# Extracting Features:  62%|██████████████▏        | 962/1561 [00:03<00:02, 284.70it/s]
# Extracting Features:  64%|██████████████▌        | 992/1561 [00:03<00:01, 287.35it/s]
# Extracting Features:  65%|██████████████▍       | 1022/1561 [00:03<00:01, 290.51it/s]
# Extracting Features:  67%|██████████████▊       | 1052/1561 [00:03<00:01, 292.48it/s]
# Extracting Features:  69%|███████████████▎      | 1083/1561 [00:03<00:01, 297.65it/s]
# Extracting Features:  71%|███████████████▋      | 1113/1561 [00:03<00:01, 296.58it/s]
# Extracting Features:  73%|████████████████      | 1144/1561 [00:03<00:01, 299.69it/s]
# Extracting Features:  75%|████████████████▌     | 1174/1561 [00:04<00:01, 295.36it/s]
# Extracting Features:  77%|████████████████▉     | 1204/1561 [00:04<00:01, 295.89it/s]
# Extracting Features:  79%|█████████████████▍    | 1234/1561 [00:04<00:01, 297.10it/s]
# Extracting Features:  81%|█████████████████▊    | 1265/1561 [00:04<00:00, 300.01it/s]
# Extracting Features:  83%|██████████████████▎   | 1296/1561 [00:04<00:00, 299.45it/s]
# Extracting Features:  85%|██████████████████▋   | 1326/1561 [00:04<00:00, 296.11it/s]
# Extracting Features:  87%|███████████████████   | 1357/1561 [00:04<00:00, 297.55it/s]
# Extracting Features:  89%|███████████████████▌  | 1388/1561 [00:04<00:00, 300.33it/s]
# Extracting Features:  91%|███████████████████▉  | 1419/1561 [00:04<00:00, 298.80it/s]
# Extracting Features:  93%|████████████████████▍ | 1450/1561 [00:04<00:00, 299.43it/s]
# Extracting Features:  95%|████████████████████▊ | 1481/1561 [00:05<00:00, 301.65it/s]
# Extracting Features:  97%|█████████████████████▎| 1512/1561 [00:05<00:00, 299.69it/s]
# Extracting Features: 100%|██████████████████████| 1561/1561 [00:05<00:00, 292.23it/s]
# Processing MergeData Chunks: 5it [00:27,  5.43s/it]2024-10-18 15:04:20,455 - INFO - Extracting features from windows...
#
# Extracting Features:   0%|                                  | 0/1561 [00:00<?, ?it/s]
# Extracting Features:   2%|▍                       | 28/1561 [00:00<00:05, 277.42it/s]
# Extracting Features:   4%|▉                       | 58/1561 [00:00<00:05, 287.86it/s]
# Extracting Features:   6%|█▎                      | 88/1561 [00:00<00:05, 292.01it/s]
# Extracting Features:   8%|█▋                     | 118/1561 [00:00<00:05, 288.39it/s]
# Extracting Features:   9%|██▏                    | 148/1561 [00:00<00:04, 289.43it/s]
# Extracting Features:  11%|██▌                    | 178/1561 [00:00<00:04, 290.04it/s]
# Extracting Features:  13%|███                    | 208/1561 [00:00<00:04, 291.36it/s]
# Extracting Features:  15%|███▌                   | 238/1561 [00:00<00:04, 290.44it/s]
# Extracting Features:  17%|███▉                   | 268/1561 [00:00<00:04, 292.47it/s]
# Extracting Features:  19%|████▍                  | 298/1561 [00:01<00:04, 290.35it/s]
# Extracting Features:  21%|████▊                  | 328/1561 [00:01<00:04, 288.06it/s]
# Extracting Features:  23%|█████▎                 | 357/1561 [00:01<00:04, 281.96it/s]
# Extracting Features:  25%|█████▋                 | 386/1561 [00:01<00:04, 270.11it/s]
# Extracting Features:  27%|██████▏                | 416/1561 [00:01<00:04, 277.00it/s]
# Extracting Features:  29%|██████▌                | 447/1561 [00:01<00:03, 284.87it/s]
# Extracting Features:  31%|███████                | 477/1561 [00:01<00:03, 288.42it/s]
# Extracting Features:  32%|███████▍               | 506/1561 [00:01<00:03, 284.70it/s]
# Extracting Features:  34%|███████▉               | 535/1561 [00:01<00:03, 283.76it/s]
# Extracting Features:  36%|████████▎              | 564/1561 [00:01<00:03, 283.10it/s]
# Extracting Features:  38%|████████▊              | 594/1561 [00:02<00:03, 285.56it/s]
# Extracting Features:  40%|█████████▏             | 624/1561 [00:02<00:03, 288.11it/s]
# Extracting Features:  42%|█████████▌             | 653/1561 [00:02<00:03, 288.32it/s]
# Extracting Features:  44%|██████████             | 682/1561 [00:02<00:03, 286.46it/s]
# Extracting Features:  46%|██████████▌            | 713/1561 [00:02<00:02, 291.69it/s]
# Extracting Features:  48%|██████████▉            | 743/1561 [00:02<00:02, 293.27it/s]
# Extracting Features:  50%|███████████▍           | 773/1561 [00:02<00:02, 292.67it/s]
# Extracting Features:  51%|███████████▊           | 803/1561 [00:02<00:02, 291.39it/s]
# Extracting Features:  53%|████████████▎          | 834/1561 [00:02<00:02, 295.13it/s]
# Extracting Features:  55%|████████████▋          | 864/1561 [00:02<00:02, 295.69it/s]
# Extracting Features:  57%|█████████████▏         | 895/1561 [00:03<00:02, 297.31it/s]
# Extracting Features:  59%|█████████████▋         | 926/1561 [00:03<00:02, 300.17it/s]
# Extracting Features:  61%|██████████████         | 957/1561 [00:03<00:02, 299.53it/s]
# Extracting Features:  63%|██████████████▌        | 987/1561 [00:03<00:01, 297.89it/s]
# Extracting Features:  65%|██████████████▎       | 1019/1561 [00:03<00:01, 301.74it/s]
# Extracting Features:  67%|██████████████▊       | 1050/1561 [00:03<00:01, 298.89it/s]
# Extracting Features:  69%|███████████████▏      | 1080/1561 [00:03<00:01, 297.48it/s]
# Extracting Features:  71%|███████████████▋      | 1110/1561 [00:03<00:01, 293.08it/s]
# Extracting Features:  73%|████████████████      | 1140/1561 [00:03<00:01, 287.54it/s]
# Extracting Features:  75%|████████████████▍     | 1169/1561 [00:04<00:01, 288.25it/s]
# Extracting Features:  77%|████████████████▉     | 1198/1561 [00:04<00:01, 285.43it/s]
# Extracting Features:  79%|█████████████████▎    | 1228/1561 [00:04<00:01, 289.65it/s]
# Extracting Features:  81%|█████████████████▊    | 1260/1561 [00:04<00:01, 296.00it/s]
# Extracting Features:  83%|██████████████████▏   | 1290/1561 [00:04<00:00, 291.44it/s]
# Extracting Features:  85%|██████████████████▌   | 1320/1561 [00:04<00:00, 290.41it/s]
# Extracting Features:  87%|███████████████████   | 1351/1561 [00:04<00:00, 293.84it/s]
# Extracting Features:  88%|███████████████████▍  | 1381/1561 [00:04<00:00, 293.95it/s]
# Extracting Features:  90%|███████████████████▉  | 1411/1561 [00:04<00:00, 294.83it/s]
# Extracting Features:  92%|████████████████████▎ | 1442/1561 [00:04<00:00, 298.45it/s]
# Extracting Features:  94%|████████████████████▊ | 1473/1561 [00:05<00:00, 299.19it/s]
# Extracting Features:  96%|█████████████████████▏| 1504/1561 [00:05<00:00, 298.87it/s]
# Extracting Features: 100%|██████████████████████| 1561/1561 [00:05<00:00, 291.22it/s]
# Processing MergeData Chunks: 6it [00:32,  5.45s/it]2024-10-18 15:04:25,938 - INFO - Extracting features from windows...
#
# Extracting Features:   0%|                                  | 0/1561 [00:00<?, ?it/s]
# Extracting Features:   2%|▍                       | 30/1561 [00:00<00:05, 288.48it/s]
# Extracting Features:   4%|▉                       | 60/1561 [00:00<00:05, 295.14it/s]
# Extracting Features:   6%|█▍                      | 90/1561 [00:00<00:04, 294.68it/s]
# Extracting Features:   8%|█▊                     | 120/1561 [00:00<00:04, 294.42it/s]
# Extracting Features:  10%|██▏                    | 150/1561 [00:00<00:04, 295.36it/s]
# Extracting Features:  12%|██▋                    | 180/1561 [00:00<00:04, 291.07it/s]
# Extracting Features:  13%|███                    | 210/1561 [00:00<00:04, 288.38it/s]
# Extracting Features:  15%|███▌                   | 239/1561 [00:00<00:04, 287.99it/s]
# Extracting Features:  17%|███▉                   | 269/1561 [00:00<00:04, 291.65it/s]
# Extracting Features:  19%|████▍                  | 299/1561 [00:01<00:04, 294.19it/s]
# Extracting Features:  21%|████▊                  | 329/1561 [00:01<00:04, 290.83it/s]
# Extracting Features:  23%|█████▎                 | 359/1561 [00:01<00:04, 291.29it/s]
# Extracting Features:  25%|█████▋                 | 389/1561 [00:01<00:04, 292.65it/s]
# Extracting Features:  27%|██████▏                | 419/1561 [00:01<00:03, 293.96it/s]
# Extracting Features:  29%|██████▋                | 450/1561 [00:01<00:03, 296.99it/s]
# Extracting Features:  31%|███████                | 481/1561 [00:01<00:03, 299.08it/s]
# Extracting Features:  33%|███████▌               | 511/1561 [00:01<00:03, 298.44it/s]
# Extracting Features:  35%|███████▉               | 541/1561 [00:01<00:03, 287.00it/s]
# Extracting Features:  37%|████████▍              | 571/1561 [00:01<00:03, 289.09it/s]
# Extracting Features:  39%|████████▊              | 602/1561 [00:02<00:03, 293.47it/s]
# Extracting Features:  40%|█████████▎             | 632/1561 [00:02<00:03, 294.49it/s]
# Extracting Features:  42%|█████████▊             | 662/1561 [00:02<00:03, 293.55it/s]
# Extracting Features:  44%|██████████▏            | 692/1561 [00:02<00:03, 287.82it/s]
# Extracting Features:  46%|██████████▋            | 722/1561 [00:02<00:02, 289.66it/s]
# Extracting Features:  48%|███████████            | 752/1561 [00:02<00:02, 289.32it/s]
# Extracting Features:  50%|███████████▌           | 781/1561 [00:02<00:02, 287.84it/s]
# Extracting Features:  52%|███████████▉           | 811/1561 [00:02<00:02, 291.38it/s]
# Extracting Features:  54%|████████████▍          | 841/1561 [00:02<00:02, 292.20it/s]
# Extracting Features:  56%|████████████▊          | 871/1561 [00:02<00:02, 291.95it/s]
# Extracting Features:  58%|█████████████▎         | 901/1561 [00:03<00:02, 290.89it/s]
# Extracting Features:  60%|█████████████▋         | 931/1561 [00:03<00:02, 286.82it/s]
# Extracting Features:  62%|██████████████▏        | 961/1561 [00:03<00:02, 288.97it/s]
# Extracting Features:  63%|██████████████▌        | 990/1561 [00:03<00:02, 284.84it/s]
# Extracting Features:  65%|██████████████▎       | 1019/1561 [00:03<00:01, 284.78it/s]
# Extracting Features:  67%|██████████████▊       | 1049/1561 [00:03<00:01, 287.56it/s]
# Extracting Features:  69%|███████████████▏      | 1079/1561 [00:03<00:01, 290.35it/s]
# Extracting Features:  71%|███████████████▋      | 1110/1561 [00:03<00:01, 293.58it/s]
# Extracting Features:  73%|████████████████      | 1140/1561 [00:03<00:01, 294.60it/s]
# Extracting Features:  75%|████████████████▍     | 1170/1561 [00:04<00:01, 294.43it/s]
# Extracting Features:  77%|████████████████▉     | 1201/1561 [00:04<00:01, 297.28it/s]
# Extracting Features:  79%|█████████████████▎    | 1231/1561 [00:04<00:01, 296.35it/s]
# Extracting Features:  81%|█████████████████▊    | 1261/1561 [00:04<00:01, 296.56it/s]
# Extracting Features:  83%|██████████████████▏   | 1291/1561 [00:04<00:00, 294.93it/s]
# Extracting Features:  85%|██████████████████▌   | 1321/1561 [00:04<00:00, 292.99it/s]
# Extracting Features:  87%|███████████████████   | 1351/1561 [00:04<00:00, 284.17it/s]
# Extracting Features:  88%|███████████████████▍  | 1380/1561 [00:04<00:00, 271.00it/s]
# Extracting Features:  90%|███████████████████▉  | 1411/1561 [00:04<00:00, 279.61it/s]
# Extracting Features:  92%|████████████████████▎ | 1440/1561 [00:04<00:00, 282.56it/s]
# Extracting Features:  94%|████████████████████▋ | 1470/1561 [00:05<00:00, 286.78it/s]
# Extracting Features:  96%|█████████████████████▏| 1499/1561 [00:05<00:00, 286.88it/s]
# Extracting Features:  98%|█████████████████████▌| 1529/1561 [00:05<00:00, 289.87it/s]
# Extracting Features: 100%|██████████████████████| 1561/1561 [00:05<00:00, 290.74it/s]
# Processing MergeData Chunks: 7it [00:38,  5.46s/it]2024-10-18 15:04:31,431 - INFO - Extracting features from windows...
#
# Extracting Features:   0%|                                  | 0/1561 [00:00<?, ?it/s]
# Extracting Features:   2%|▍                       | 28/1561 [00:00<00:05, 279.40it/s]
# Extracting Features:   4%|▉                       | 57/1561 [00:00<00:05, 282.31it/s]
# Extracting Features:   6%|█▎                      | 87/1561 [00:00<00:05, 287.68it/s]
# Extracting Features:   8%|█▋                     | 118/1561 [00:00<00:04, 294.11it/s]
# Extracting Features:   9%|██▏                    | 148/1561 [00:00<00:04, 294.14it/s]
# Extracting Features:  11%|██▋                    | 179/1561 [00:00<00:04, 297.44it/s]
# Extracting Features:  13%|███                    | 210/1561 [00:00<00:04, 298.63it/s]
# Extracting Features:  15%|███▌                   | 241/1561 [00:00<00:04, 301.22it/s]
# Extracting Features:  17%|████                   | 272/1561 [00:00<00:04, 297.53it/s]
# Extracting Features:  19%|████▍                  | 302/1561 [00:01<00:04, 293.85it/s]
# Extracting Features:  21%|████▉                  | 332/1561 [00:01<00:04, 288.77it/s]
# Extracting Features:  23%|█████▎                 | 362/1561 [00:01<00:04, 291.24it/s]
# Extracting Features:  25%|█████▊                 | 392/1561 [00:01<00:03, 292.96it/s]
# Extracting Features:  27%|██████▏                | 422/1561 [00:01<00:03, 290.71it/s]
# Extracting Features:  29%|██████▋                | 452/1561 [00:01<00:03, 291.73it/s]
# Extracting Features:  31%|███████                | 482/1561 [00:01<00:03, 287.39it/s]
# Extracting Features:  33%|███████▌               | 511/1561 [00:01<00:03, 286.48it/s]
# Extracting Features:  35%|███████▉               | 541/1561 [00:01<00:03, 289.62it/s]
# Extracting Features:  37%|████████▍              | 571/1561 [00:01<00:03, 290.11it/s]
# Extracting Features:  39%|████████▊              | 601/1561 [00:02<00:03, 292.13it/s]
# Extracting Features:  40%|█████████▎             | 631/1561 [00:02<00:03, 292.73it/s]
# Extracting Features:  42%|█████████▋             | 661/1561 [00:02<00:03, 288.07it/s]
# Extracting Features:  44%|██████████▏            | 690/1561 [00:02<00:03, 287.56it/s]
# Extracting Features:  46%|██████████▌            | 721/1561 [00:02<00:02, 291.87it/s]
# Extracting Features:  48%|███████████            | 751/1561 [00:02<00:02, 293.42it/s]
# Extracting Features:  50%|███████████▌           | 782/1561 [00:02<00:02, 296.57it/s]
# Extracting Features:  52%|███████████▉           | 812/1561 [00:02<00:02, 295.80it/s]
# Extracting Features:  54%|████████████▍          | 842/1561 [00:02<00:02, 296.17it/s]
# Extracting Features:  56%|████████████▊          | 872/1561 [00:02<00:02, 293.85it/s]
# Extracting Features:  58%|█████████████▎         | 902/1561 [00:03<00:02, 293.04it/s]
# Extracting Features:  60%|█████████████▋         | 933/1561 [00:03<00:02, 295.46it/s]
# Extracting Features:  62%|██████████████▏        | 963/1561 [00:03<00:02, 295.05it/s]
# Extracting Features:  64%|██████████████▋        | 993/1561 [00:03<00:01, 293.89it/s]
# Extracting Features:  66%|██████████████▍       | 1024/1561 [00:03<00:01, 296.88it/s]
# Extracting Features:  68%|██████████████▊       | 1055/1561 [00:03<00:01, 298.98it/s]
# Extracting Features:  70%|███████████████▎      | 1086/1561 [00:03<00:01, 299.60it/s]
# Extracting Features:  71%|███████████████▋      | 1116/1561 [00:03<00:01, 293.66it/s]
# Extracting Features:  73%|████████████████▏     | 1146/1561 [00:03<00:01, 292.07it/s]
# Extracting Features:  75%|████████████████▌     | 1176/1561 [00:04<00:01, 293.55it/s]
# Extracting Features:  77%|████████████████▉     | 1206/1561 [00:04<00:01, 295.43it/s]
# Extracting Features:  79%|█████████████████▍    | 1237/1561 [00:04<00:01, 297.99it/s]
# Extracting Features:  81%|█████████████████▊    | 1267/1561 [00:04<00:00, 295.08it/s]
# Extracting Features:  83%|██████████████████▎   | 1297/1561 [00:04<00:00, 294.82it/s]
# Extracting Features:  85%|██████████████████▋   | 1327/1561 [00:04<00:00, 291.90it/s]
# Extracting Features:  87%|███████████████████   | 1357/1561 [00:04<00:00, 292.89it/s]
# Extracting Features:  89%|███████████████████▌  | 1388/1561 [00:04<00:00, 297.08it/s]
# Extracting Features:  91%|███████████████████▉  | 1418/1561 [00:04<00:00, 293.60it/s]
# Extracting Features:  93%|████████████████████▍ | 1448/1561 [00:04<00:00, 292.05it/s]
# Extracting Features:  95%|████████████████████▊ | 1478/1561 [00:05<00:00, 289.29it/s]
# Extracting Features:  97%|█████████████████████▏| 1507/1561 [00:05<00:00, 282.88it/s]
# Extracting Features: 100%|██████████████████████| 1561/1561 [00:05<00:00, 292.44it/s]
# Processing MergeData Chunks: 8it [00:43,  5.46s/it]2024-10-18 15:04:36,889 - INFO - Extracting features from windows...
#
# Extracting Features:   0%|                                  | 0/1561 [00:00<?, ?it/s]
# Extracting Features:   2%|▍                       | 30/1561 [00:00<00:05, 299.98it/s]
# Extracting Features:   4%|▉                       | 60/1561 [00:00<00:05, 299.99it/s]
# Extracting Features:   6%|█▍                      | 91/1561 [00:00<00:04, 301.81it/s]
# Extracting Features:   8%|█▊                     | 122/1561 [00:00<00:04, 296.83it/s]
# Extracting Features:  10%|██▏                    | 152/1561 [00:00<00:04, 296.93it/s]
# Extracting Features:  12%|██▋                    | 182/1561 [00:00<00:04, 295.95it/s]
# Extracting Features:  14%|███                    | 212/1561 [00:00<00:04, 295.38it/s]
# Extracting Features:  16%|███▌                   | 242/1561 [00:00<00:04, 296.83it/s]
# Extracting Features:  17%|████                   | 272/1561 [00:00<00:04, 296.89it/s]
# Extracting Features:  19%|████▍                  | 303/1561 [00:01<00:04, 299.07it/s]
# Extracting Features:  21%|████▉                  | 334/1561 [00:01<00:04, 300.56it/s]
# Extracting Features:  23%|█████▍                 | 365/1561 [00:01<00:04, 296.34it/s]
# Extracting Features:  25%|█████▊                 | 395/1561 [00:01<00:03, 295.74it/s]
# Extracting Features:  27%|██████▎                | 425/1561 [00:01<00:03, 296.89it/s]
# Extracting Features:  29%|██████▋                | 455/1561 [00:01<00:03, 297.78it/s]
# Extracting Features:  31%|███████▏               | 486/1561 [00:01<00:03, 299.64it/s]
# Extracting Features:  33%|███████▌               | 517/1561 [00:01<00:03, 300.07it/s]
# Extracting Features:  35%|████████               | 548/1561 [00:01<00:03, 300.34it/s]
# Extracting Features:  37%|████████▌              | 579/1561 [00:01<00:03, 303.17it/s]
# Extracting Features:  39%|████████▉              | 610/1561 [00:02<00:03, 301.61it/s]
# Extracting Features:  41%|█████████▍             | 641/1561 [00:02<00:03, 303.22it/s]
# Extracting Features:  43%|█████████▉             | 672/1561 [00:02<00:02, 302.51it/s]
# Extracting Features:  45%|██████████▎            | 703/1561 [00:02<00:02, 302.96it/s]
# Extracting Features:  47%|██████████▊            | 734/1561 [00:02<00:02, 301.48it/s]
# Extracting Features:  49%|███████████▎           | 765/1561 [00:02<00:02, 303.10it/s]
# Extracting Features:  51%|███████████▋           | 796/1561 [00:02<00:02, 301.54it/s]
# Extracting Features:  53%|████████████▏          | 827/1561 [00:02<00:02, 302.28it/s]
# Extracting Features:  55%|████████████▋          | 858/1561 [00:02<00:02, 288.40it/s]
# Extracting Features:  57%|█████████████          | 888/1561 [00:02<00:02, 290.88it/s]
# Extracting Features:  59%|█████████████▌         | 919/1561 [00:03<00:02, 295.55it/s]
# Extracting Features:  61%|█████████████▉         | 949/1561 [00:03<00:02, 295.95it/s]
# Extracting Features:  63%|██████████████▍        | 980/1561 [00:03<00:01, 298.33it/s]
# Extracting Features:  65%|██████████████▏       | 1010/1561 [00:03<00:01, 297.97it/s]
# Extracting Features:  67%|██████████████▋       | 1040/1561 [00:03<00:01, 294.78it/s]
# Extracting Features:  69%|███████████████       | 1071/1561 [00:03<00:01, 296.78it/s]
# Extracting Features:  71%|███████████████▌      | 1101/1561 [00:03<00:01, 294.26it/s]
# Extracting Features:  72%|███████████████▉      | 1131/1561 [00:03<00:01, 293.34it/s]
# Extracting Features:  74%|████████████████▎     | 1161/1561 [00:03<00:01, 293.59it/s]
# Extracting Features:  76%|████████████████▊     | 1191/1561 [00:04<00:01, 293.73it/s]
# Extracting Features:  78%|█████████████████▏    | 1221/1561 [00:04<00:01, 292.99it/s]
# Extracting Features:  80%|█████████████████▋    | 1251/1561 [00:04<00:01, 294.20it/s]
# Extracting Features:  82%|██████████████████    | 1282/1561 [00:04<00:00, 295.38it/s]
# Extracting Features:  84%|██████████████████▍   | 1312/1561 [00:04<00:00, 293.29it/s]
# Extracting Features:  86%|██████████████████▉   | 1342/1561 [00:04<00:00, 292.62it/s]
# Extracting Features:  88%|███████████████████▎  | 1373/1561 [00:04<00:00, 295.12it/s]
# Extracting Features:  90%|███████████████████▊  | 1403/1561 [00:04<00:00, 292.26it/s]
# Extracting Features:  92%|████████████████████▏ | 1433/1561 [00:04<00:00, 292.84it/s]
# Extracting Features:  94%|████████████████████▌ | 1463/1561 [00:04<00:00, 294.08it/s]
# Extracting Features:  96%|█████████████████████ | 1494/1561 [00:05<00:00, 297.02it/s]
# Extracting Features:  98%|█████████████████████▍| 1524/1561 [00:05<00:00, 297.02it/s]
# Extracting Features: 100%|██████████████████████| 1561/1561 [00:05<00:00, 296.76it/s]
# Processing MergeData Chunks: 9it [00:48,  5.44s/it]2024-10-18 15:04:42,273 - INFO - Extracting features from windows...
#
# Extracting Features:   0%|                                  | 0/1561 [00:00<?, ?it/s]
# Extracting Features:   2%|▍                       | 30/1561 [00:00<00:05, 297.01it/s]
# Extracting Features:   4%|▉                       | 60/1561 [00:00<00:05, 293.03it/s]
# Extracting Features:   6%|█▍                      | 90/1561 [00:00<00:05, 285.70it/s]
# Extracting Features:   8%|█▊                     | 119/1561 [00:00<00:05, 287.12it/s]
# Extracting Features:   9%|██▏                    | 148/1561 [00:00<00:04, 286.11it/s]
# Extracting Features:  11%|██▌                    | 177/1561 [00:00<00:04, 285.50it/s]
# Extracting Features:  13%|███                    | 207/1561 [00:00<00:04, 289.21it/s]
# Extracting Features:  15%|███▍                   | 237/1561 [00:00<00:04, 290.80it/s]
# Extracting Features:  17%|███▉                   | 267/1561 [00:00<00:04, 292.70it/s]
# Extracting Features:  19%|████▍                  | 298/1561 [00:01<00:04, 294.42it/s]
# Extracting Features:  21%|████▊                  | 328/1561 [00:01<00:04, 292.54it/s]
# Extracting Features:  23%|█████▎                 | 358/1561 [00:01<00:04, 293.89it/s]
# Extracting Features:  25%|█████▋                 | 388/1561 [00:01<00:03, 295.71it/s]
# Extracting Features:  27%|██████▏                | 418/1561 [00:01<00:03, 295.26it/s]
# Extracting Features:  29%|██████▌                | 449/1561 [00:01<00:03, 298.76it/s]
# Extracting Features:  31%|███████                | 480/1561 [00:01<00:03, 301.21it/s]
# Extracting Features:  33%|███████▌               | 511/1561 [00:01<00:03, 298.49it/s]
# Extracting Features:  35%|███████▉               | 541/1561 [00:01<00:03, 297.19it/s]
# Extracting Features:  37%|████████▍              | 571/1561 [00:01<00:03, 293.68it/s]
# Extracting Features:  39%|████████▊              | 601/1561 [00:02<00:03, 290.42it/s]
# Extracting Features:  40%|█████████▎             | 631/1561 [00:02<00:03, 292.37it/s]
# Extracting Features:  42%|█████████▋             | 661/1561 [00:02<00:03, 292.89it/s]
# Extracting Features:  44%|██████████▏            | 691/1561 [00:02<00:02, 294.11it/s]
# Extracting Features:  46%|██████████▌            | 721/1561 [00:02<00:02, 289.03it/s]
# Extracting Features:  48%|███████████            | 751/1561 [00:02<00:02, 290.15it/s]
# Extracting Features:  50%|███████████▌           | 781/1561 [00:02<00:02, 267.22it/s]
# Extracting Features:  52%|███████████▉           | 810/1561 [00:02<00:02, 272.01it/s]
# Extracting Features:  54%|████████████▍          | 840/1561 [00:02<00:02, 279.11it/s]
# Extracting Features:  56%|████████████▊          | 869/1561 [00:03<00:02, 281.42it/s]
# Extracting Features:  58%|█████████████▏         | 899/1561 [00:03<00:02, 285.15it/s]
# Extracting Features:  60%|█████████████▋         | 929/1561 [00:03<00:02, 287.80it/s]
# Extracting Features:  61%|██████████████         | 958/1561 [00:03<00:02, 288.44it/s]
# Extracting Features:  63%|██████████████▌        | 988/1561 [00:03<00:01, 290.97it/s]
# Extracting Features:  65%|██████████████▎       | 1019/1561 [00:03<00:01, 294.02it/s]
# Extracting Features:  67%|██████████████▊       | 1049/1561 [00:03<00:01, 294.05it/s]
# Extracting Features:  69%|███████████████▏      | 1079/1561 [00:03<00:01, 294.07it/s]
# Extracting Features:  71%|███████████████▋      | 1109/1561 [00:03<00:01, 294.08it/s]
# Extracting Features:  73%|████████████████      | 1140/1561 [00:03<00:01, 297.03it/s]
# Extracting Features:  75%|████████████████▌     | 1171/1561 [00:04<00:01, 298.20it/s]
# Extracting Features:  77%|████████████████▉     | 1201/1561 [00:04<00:01, 297.88it/s]
# Extracting Features:  79%|█████████████████▎    | 1232/1561 [00:04<00:01, 300.55it/s]
# Extracting Features:  81%|█████████████████▊    | 1263/1561 [00:04<00:01, 296.34it/s]
# Extracting Features:  83%|██████████████████▏   | 1293/1561 [00:04<00:00, 293.97it/s]
# Extracting Features:  85%|██████████████████▋   | 1324/1561 [00:04<00:00, 296.92it/s]
# Extracting Features:  87%|███████████████████   | 1354/1561 [00:04<00:00, 294.11it/s]
# Extracting Features:  89%|███████████████████▌  | 1384/1561 [00:04<00:00, 292.13it/s]
# Extracting Features:  91%|███████████████████▉  | 1414/1561 [00:04<00:00, 292.20it/s]
# Extracting Features:  93%|████████████████████▎ | 1445/1561 [00:04<00:00, 293.98it/s]
# Extracting Features:  94%|████████████████████▊ | 1475/1561 [00:05<00:00, 294.88it/s]
# Extracting Features:  96%|█████████████████████▏| 1505/1561 [00:05<00:00, 291.25it/s]
# Extracting Features: 100%|██████████████████████| 1561/1561 [00:05<00:00, 291.37it/s]
# Processing MergeData Chunks: 10it [00:54,  5.45s/it]2024-10-18 15:04:47,758 - INFO - Extracting features from windows...
#
# Extracting Features:   0%|                                  | 0/1561 [00:00<?, ?it/s]
# Extracting Features:   2%|▍                       | 30/1561 [00:00<00:05, 288.37it/s]
# Extracting Features:   4%|▉                       | 59/1561 [00:00<00:06, 238.33it/s]
# Extracting Features:   6%|█▎                      | 88/1561 [00:00<00:05, 258.22it/s]
# Extracting Features:   8%|█▋                     | 118/1561 [00:00<00:05, 271.51it/s]
# Extracting Features:   9%|██▏                    | 148/1561 [00:00<00:05, 280.28it/s]
# Extracting Features:  11%|██▌                    | 177/1561 [00:00<00:04, 282.54it/s]
# Extracting Features:  13%|███                    | 207/1561 [00:00<00:04, 287.17it/s]
# Extracting Features:  15%|███▍                   | 237/1561 [00:00<00:04, 290.24it/s]
# Extracting Features:  17%|███▉                   | 267/1561 [00:00<00:04, 292.34it/s]
# Extracting Features:  19%|████▍                  | 298/1561 [00:01<00:04, 295.05it/s]
# Extracting Features:  21%|████▊                  | 328/1561 [00:01<00:04, 293.88it/s]
# Extracting Features:  23%|█████▎                 | 359/1561 [00:01<00:04, 296.90it/s]
# Extracting Features:  25%|█████▋                 | 389/1561 [00:01<00:03, 294.53it/s]
# Extracting Features:  27%|██████▏                | 419/1561 [00:01<00:03, 289.47it/s]
# Extracting Features:  29%|██████▌                | 449/1561 [00:01<00:03, 290.71it/s]
# Extracting Features:  31%|███████                | 479/1561 [00:01<00:03, 293.44it/s]
# Extracting Features:  33%|███████▍               | 509/1561 [00:01<00:03, 294.51it/s]
# Extracting Features:  35%|███████▉               | 539/1561 [00:01<00:03, 294.39it/s]
# Extracting Features:  36%|████████▍              | 569/1561 [00:01<00:03, 296.05it/s]
# ...
# Extracting Features:  90%|███████████████████▋  | 1401/1561 [00:04<00:00, 318.57it/s]
# Extracting Features:  92%|████████████████████▏ | 1433/1561 [00:04<00:00, 313.42it/s]
# Extracting Features:  94%|████████████████████▋ | 1465/1561 [00:04<00:00, 308.97it/s]
# Extracting Features:  96%|█████████████████████ | 1498/1561 [00:04<00:00, 312.37it/s]
# Extracting Features: 100%|██████████████████████| 1561/1561 [00:05<00:00, 311.85it/s]
# Processing MergeData Chunks: 1876it [2:47:25,  5.13s/it]2024-10-18 17:51:18,688 - INFO - Extracting features from windows...
#
# Extracting Features:   0%|                                  | 0/1561 [00:00<?, ?it/s]
# Extracting Features:   2%|▍                       | 29/1561 [00:00<00:05, 286.14it/s]
# Extracting Features:   4%|▉                       | 59/1561 [00:00<00:05, 294.04it/s]
# Extracting Features:   6%|█▍                      | 91/1561 [00:00<00:04, 302.37it/s]
# Extracting Features:   8%|█▊                     | 123/1561 [00:00<00:04, 308.02it/s]
# Extracting Features:  10%|██▎                    | 155/1561 [00:00<00:04, 310.12it/s]
# Extracting Features:  12%|██▊                    | 187/1561 [00:00<00:04, 309.28it/s]
# Extracting Features:  14%|███▏                   | 218/1561 [00:00<00:04, 306.55it/s]
# Extracting Features:  16%|███▋                   | 249/1561 [00:00<00:04, 305.72it/s]
# Extracting Features:  18%|████▏                  | 280/1561 [00:00<00:04, 305.16it/s]
# Extracting Features:  20%|████▌                  | 311/1561 [00:01<00:04, 304.75it/s]
# Extracting Features:  22%|█████                  | 342/1561 [00:01<00:03, 305.41it/s]
# Extracting Features:  24%|█████▌                 | 375/1561 [00:01<00:03, 309.11it/s]
# Extracting Features:  26%|█████▉                 | 406/1561 [00:01<00:03, 308.46it/s]
# Extracting Features:  28%|██████▍                | 438/1561 [00:01<00:03, 310.02it/s]
# Extracting Features:  30%|██████▉                | 469/1561 [00:01<00:03, 309.10it/s]
# Extracting Features:  32%|███████▎               | 500/1561 [00:01<00:03, 309.36it/s]
# Extracting Features:  34%|███████▊               | 532/1561 [00:01<00:03, 310.68it/s]
# Extracting Features:  36%|████████▎              | 564/1561 [00:01<00:03, 309.77it/s]
# Extracting Features:  38%|████████▊              | 595/1561 [00:01<00:03, 309.84it/s]
# Extracting Features:  40%|█████████▏             | 626/1561 [00:02<00:03, 306.27it/s]
# Extracting Features:  42%|█████████▋             | 659/1561 [00:02<00:02, 310.53it/s]
# Extracting Features:  44%|██████████▏            | 691/1561 [00:02<00:02, 310.58it/s]
# Extracting Features:  46%|██████████▋            | 723/1561 [00:02<00:02, 308.10it/s]
# Extracting Features:  48%|███████████            | 755/1561 [00:02<00:02, 310.14it/s]
# Extracting Features:  50%|███████████▌           | 787/1561 [00:02<00:02, 313.01it/s]
# Extracting Features:  52%|████████████           | 819/1561 [00:02<00:02, 312.33it/s]
# Extracting Features:  55%|████████████▌          | 851/1561 [00:02<00:02, 313.64it/s]
# Extracting Features:  57%|█████████████          | 883/1561 [00:02<00:02, 313.70it/s]
# Extracting Features:  59%|█████████████▍         | 915/1561 [00:02<00:02, 315.53it/s]
# Extracting Features:  61%|█████████████▉         | 947/1561 [00:03<00:01, 315.92it/s]
# Extracting Features:  63%|██████████████▍        | 979/1561 [00:03<00:01, 315.29it/s]
# Extracting Features:  65%|██████████████▏       | 1011/1561 [00:03<00:01, 314.79it/s]
# Extracting Features:  67%|██████████████▋       | 1043/1561 [00:03<00:01, 314.47it/s]
# Extracting Features:  69%|███████████████▏      | 1075/1561 [00:03<00:01, 315.17it/s]
# Extracting Features:  71%|███████████████▌      | 1108/1561 [00:03<00:01, 316.78it/s]
# Extracting Features:  73%|████████████████      | 1140/1561 [00:03<00:01, 313.10it/s]
# Extracting Features:  75%|████████████████▌     | 1172/1561 [00:03<00:01, 304.39it/s]
# Extracting Features:  77%|████████████████▉     | 1203/1561 [00:03<00:01, 304.25it/s]
# Extracting Features:  79%|█████████████████▍    | 1234/1561 [00:03<00:01, 304.15it/s]
# Extracting Features:  81%|█████████████████▊    | 1266/1561 [00:04<00:00, 306.10it/s]
# Extracting Features:  83%|██████████████████▎   | 1297/1561 [00:04<00:00, 304.57it/s]
# Extracting Features:  85%|██████████████████▋   | 1328/1561 [00:04<00:00, 300.87it/s]
# Extracting Features:  87%|███████████████████▏  | 1359/1561 [00:04<00:00, 290.82it/s]
# Extracting Features:  89%|███████████████████▌  | 1389/1561 [00:04<00:00, 286.46it/s]
# Extracting Features:  91%|████████████████████  | 1420/1561 [00:04<00:00, 292.28it/s]
# Extracting Features:  93%|████████████████████▍ | 1452/1561 [00:04<00:00, 297.72it/s]
# Extracting Features:  95%|████████████████████▉ | 1483/1561 [00:04<00:00, 299.55it/s]
# Extracting Features:  97%|█████████████████████▎| 1514/1561 [00:04<00:00, 299.99it/s]
# Extracting Features: 100%|██████████████████████| 1561/1561 [00:05<00:00, 306.87it/s]
# Processing MergeData Chunks: 1877it [2:47:30,  5.15s/it]2024-10-18 17:51:23,896 - INFO - Extracting features from windows...
#
# Extracting Features:   0%|                                  | 0/1561 [00:00<?, ?it/s]
# Extracting Features:   2%|▌                       | 33/1561 [00:00<00:04, 320.47it/s]
# Extracting Features:  14%|███▎                   | 225/1561 [00:00<00:04, 308.43it/s]
# Extracting Features:  16%|███▊                   | 256/1561 [00:00<00:04, 307.97it/s]
# Extracting Features:  18%|████▏                  | 287/1561 [00:00<00:04, 306.68it/s]
# Extracting Features:  20%|████▋                  | 318/1561 [00:01<00:04, 304.03it/s]
# Extracting Features:  22%|█████▏                 | 351/1561 [00:01<00:03, 309.03it/s]
# Extracting Features:  25%|█████▋                 | 383/1561 [00:01<00:03, 311.34it/s]
# Extracting Features:  27%|██████                 | 415/1561 [00:01<00:03, 311.14it/s]
# Extracting Features:  29%|██████▌                | 447/1561 [00:01<00:03, 310.12it/s]
# Extracting Features:  31%|███████                | 479/1561 [00:01<00:03, 304.06it/s]
# Extracting Features:  33%|███████▌               | 510/1561 [00:01<00:03, 302.82it/s]
# Extracting Features:  35%|███████▉               | 542/1561 [00:01<00:03, 306.83it/s]
# Extracting Features:  37%|████████▍              | 574/1561 [00:01<00:03, 309.21it/s]
# Extracting Features:  39%|████████▉              | 606/1561 [00:01<00:03, 309.68it/s]
# Extracting Features:  41%|█████████▍             | 637/1561 [00:02<00:02, 309.77it/s]
# Extracting Features:  43%|█████████▊             | 668/1561 [00:02<00:02, 308.02it/s]
# Extracting Features:  45%|██████████▎            | 699/1561 [00:02<00:02, 304.99it/s]
# Extracting Features:  47%|██████████▊            | 730/1561 [00:02<00:02, 302.02it/s]
# Extracting Features:  49%|███████████▏           | 761/1561 [00:02<00:02, 303.47it/s]
# Extracting Features:  51%|███████████▋           | 792/1561 [00:02<00:02, 302.72it/s]
# Extracting Features:  53%|████████████▏          | 825/1561 [00:02<00:02, 308.93it/s]
# Extracting Features:  55%|████████████▋          | 857/1561 [00:02<00:02, 312.17it/s]
# Extracting Features:  57%|█████████████          | 890/1561 [00:02<00:02, 313.73it/s]
# Extracting Features:  59%|█████████████▌         | 922/1561 [00:02<00:02, 311.02it/s]
# Extracting Features:  61%|██████████████         | 954/1561 [00:03<00:01, 308.23it/s]
# Extracting Features:  63%|██████████████▌        | 985/1561 [00:03<00:01, 306.07it/s]
# Extracting Features:  65%|██████████████▎       | 1017/1561 [00:03<00:01, 307.45it/s]
# Extracting Features:  67%|██████████████▊       | 1048/1561 [00:03<00:01, 307.26it/s]
# Extracting Features:  69%|███████████████▏      | 1080/1561 [00:03<00:01, 309.19it/s]
# Extracting Features:  71%|███████████████▋      | 1113/1561 [00:03<00:01, 313.48it/s]
# Extracting Features:  73%|████████████████▏     | 1145/1561 [00:03<00:01, 310.84it/s]
# Extracting Features:  75%|████████████████▌     | 1177/1561 [00:03<00:01, 307.22it/s]
# Extracting Features:  77%|█████████████████     | 1208/1561 [00:03<00:01, 304.57it/s]
# Extracting Features:  79%|█████████████████▍    | 1239/1561 [00:04<00:01, 300.76it/s]
# Extracting Features:  81%|█████████████████▉    | 1271/1561 [00:04<00:00, 303.70it/s]
# Extracting Features:  83%|██████████████████▎   | 1303/1561 [00:04<00:00, 307.55it/s]
# Extracting Features:  86%|██████████████████▊   | 1335/1561 [00:04<00:00, 309.39it/s]
# Extracting Features:  88%|███████████████████▎  | 1366/1561 [00:04<00:00, 305.08it/s]
# Extracting Features:  89%|███████████████████▋  | 1397/1561 [00:04<00:00, 290.37it/s]
# Extracting Features:  91%|████████████████████▏ | 1428/1561 [00:04<00:00, 295.10it/s]
# Extracting Features:  93%|████████████████████▌ | 1459/1561 [00:04<00:00, 298.53it/s]
# Extracting Features:  95%|████████████████████▉ | 1490/1561 [00:04<00:00, 300.99it/s]
# Extracting Features:  98%|█████████████████████▍| 1523/1561 [00:04<00:00, 306.79it/s]
# Extracting Features: 100%|██████████████████████| 1561/1561 [00:05<00:00, 306.79it/s]
# Processing MergeData Chunks: 1958it [2:54:31,  5.21s/it]2024-10-18 17:58:24,543 - INFO - Extracting features from windows...
#
# Extracting Features:   0%|                                  | 0/1561 [00:00<?, ?it/s]
# Extracting Features:   2%|▍                       | 31/1561 [00:00<00:05, 303.92it/s]
# Extracting Features:   4%|▉                       | 62/1561 [00:00<00:04, 303.87it/s]
# Extracting Features:   6%|█▍                      | 95/1561 [00:00<00:04, 311.45it/s]
# Extracting Features:   8%|█▊                     | 127/1561 [00:00<00:04, 308.81it/s]
# Extracting Features:  10%|██▎                    | 160/1561 [00:00<00:04, 312.97it/s]
# Extracting Features:  12%|██▊                    | 192/1561 [00:00<00:04, 314.23it/s]
# Extracting Features:  14%|███▎                   | 224/1561 [00:00<00:04, 312.10it/s]
# Extracting Features:  16%|███▊                   | 256/1561 [00:00<00:04, 303.88it/s]
# Extracting Features:  18%|████▏                  | 287/1561 [00:00<00:04, 302.82it/s]
# Extracting Features:  20%|████▋                  | 319/1561 [00:01<00:04, 305.54it/s]
# Extracting Features:  22%|█████▏                 | 351/1561 [00:01<00:03, 309.80it/s]
# Extracting Features:  25%|█████▋                 | 383/1561 [00:01<00:03, 309.16it/s]
# Extracting Features:  27%|██████▏                | 416/1561 [00:01<00:03, 312.59it/s]
# Extracting Features:  29%|██████▌                | 448/1561 [00:01<00:03, 312.93it/s]
# Extracting Features:  31%|███████                | 480/1561 [00:01<00:03, 314.09it/s]
# Extracting Features:  33%|███████▌               | 512/1561 [00:01<00:03, 303.26it/s]
# Extracting Features:  35%|████████               | 543/1561 [00:01<00:03, 303.46it/s]
# Extracting Features:  37%|████████▍              | 576/1561 [00:01<00:03, 309.35it/s]
# Extracting Features:  39%|████████▉              | 609/1561 [00:01<00:03, 312.68it/s]
# Extracting Features:  41%|█████████▍             | 641/1561 [00:02<00:02, 313.87it/s]
# Extracting Features:  43%|█████████▉             | 673/1561 [00:02<00:02, 313.86it/s]
# Extracting Features:  45%|██████████▍            | 705/1561 [00:02<00:02, 314.74it/s]
# Extracting Features:  47%|██████████▊            | 737/1561 [00:02<00:02, 313.51it/s]
# Extracting Features:  49%|███████████▎           | 769/1561 [00:02<00:02, 309.94it/s]
# Extracting Features:  51%|███████████▊           | 801/1561 [00:02<00:02, 310.16it/s]
# Extracting Features:  53%|████████████▎          | 833/1561 [00:02<00:02, 309.42it/s]
# Extracting Features:  55%|████████████▋          | 865/1561 [00:02<00:02, 312.49it/s]
# Extracting Features:  57%|█████████████▏         | 897/1561 [00:02<00:02, 313.78it/s]
# Extracting Features:  60%|█████████████▋         | 929/1561 [00:02<00:02, 311.95it/s]
# Extracting Features:  62%|██████████████▏        | 961/1561 [00:03<00:01, 310.23it/s]
# Extracting Features:  64%|██████████████▋        | 993/1561 [00:03<00:01, 302.84it/s]
# Extracting Features:  66%|██████████████▍       | 1024/1561 [00:03<00:01, 302.26it/s]
# Extracting Features:  68%|██████████████▉       | 1056/1561 [00:03<00:01, 305.66it/s]
# Extracting Features:  70%|███████████████▎      | 1088/1561 [00:03<00:01, 308.91it/s]
# Extracting Features:  72%|███████████████▊      | 1120/1561 [00:03<00:01, 310.35it/s]
# Extracting Features:  74%|████████████████▏     | 1152/1561 [00:03<00:01, 309.57it/s]
# Extracting Features:  76%|████████████████▋     | 1183/1561 [00:03<00:01, 308.79it/s]
# Extracting Features:  78%|█████████████████     | 1215/1561 [00:03<00:01, 311.18it/s]
# Extracting Features:  80%|█████████████████▌    | 1247/1561 [00:04<00:01, 307.42it/s]
# Extracting Features:  82%|██████████████████    | 1278/1561 [00:04<00:00, 301.99it/s]
# Extracting Features:  84%|██████████████████▍   | 1309/1561 [00:04<00:00, 303.44it/s]
# Extracting Features:  86%|██████████████████▉   | 1340/1561 [00:04<00:00, 305.36it/s]
# Extracting Features:  88%|███████████████████▎  | 1371/1561 [00:04<00:00, 305.83it/s]
# Extracting Features:  90%|███████████████████▊  | 1403/1561 [00:04<00:00, 308.20it/s]
# Extracting Features:  92%|████████████████████▏ | 1434/1561 [00:04<00:00, 308.73it/s]
# Extracting Features:  94%|████████████████████▋ | 1465/1561 [00:04<00:00, 308.19it/s]
# Extracting Features:  96%|█████████████████████ | 1496/1561 [00:04<00:00, 303.32it/s]
# Extracting Features:  98%|█████████████████████▌| 1527/1561 [00:04<00:00, 301.73it/s]
# Extracting Features: 100%|██████████████████████| 1561/1561 [00:05<00:00, 308.25it/s]
# Processing MergeData Chunks: 1959it [2:54:36,  5.21s/it]2024-10-18 17:58:29,737 - INFO - Extracting features from windows...
#
# Extracting Features:   0%|                                  | 0/1561 [00:00<?, ?it/s]
# Extracting Features:   2%|▍                       | 32/1561 [00:00<00:04, 313.85it/s]
# Extracting Features:   4%|▉                       | 64/1561 [00:00<00:04, 314.68it/s]
# Extracting Features:   6%|█▍                      | 96/1561 [00:00<00:04, 314.24it/s]
# Extracting Features:   8%|█▉                     | 128/1561 [00:00<00:04, 309.25it/s]
# Extracting Features:  10%|██▎                    | 159/1561 [00:00<00:04, 302.05it/s]
# Extracting Features:  12%|██▊                    | 191/1561 [00:00<00:04, 305.95it/s]
# Extracting Features:  14%|███▎                   | 223/1561 [00:00<00:04, 309.44it/s]
# Extracting Features:  16%|███▊                   | 255/1561 [00:00<00:04, 310.80it/s]
# Extracting Features:  18%|████▏                  | 287/1561 [00:00<00:04, 311.68it/s]
# Extracting Features:  20%|████▋                  | 319/1561 [00:01<00:03, 311.40it/s]
# Extracting Features:  22%|█████▏                 | 351/1561 [00:01<00:03, 308.39it/s]
# Extracting Features:  24%|█████▋                 | 382/1561 [00:01<00:03, 307.98it/s]
# Extracting Features:  26%|██████                 | 413/1561 [00:01<00:03, 306.76it/s]
# Extracting Features:  29%|██████▌                | 445/1561 [00:01<00:03, 308.83it/s]
# Extracting Features:  31%|███████                | 478/1561 [00:01<00:03, 312.33it/s]
# Extracting Features:  33%|███████▌               | 510/1561 [00:01<00:03, 314.59it/s]
# Extracting Features:  35%|███████▉               | 542/1561 [00:01<00:03, 313.44it/s]
# Extracting Features:  37%|████████▍              | 574/1561 [00:01<00:03, 308.08it/s]
# Extracting Features:  39%|████████▉              | 605/1561 [00:01<00:03, 308.64it/s]
# Extracting Features:  41%|█████████▎             | 636/1561 [00:02<00:03, 307.23it/s]
# Extracting Features:  43%|█████████▊             | 667/1561 [00:02<00:02, 304.46it/s]
# Extracting Features:  45%|██████████▎            | 698/1561 [00:02<00:02, 302.14it/s]
# Extracting Features:  47%|██████████▊            | 730/1561 [00:02<00:02, 304.62it/s]
# Extracting Features:  49%|███████████▏           | 762/1561 [00:02<00:02, 308.22it/s]
# Extracting Features:  51%|███████████▋           | 795/1561 [00:02<00:02, 312.76it/s]
# Extracting Features:  53%|████████████▏          | 827/1561 [00:02<00:02, 314.00it/s]
# Extracting Features:  55%|████████████▋          | 859/1561 [00:02<00:02, 313.00it/s]
# Extracting Features:  57%|█████████████▏         | 891/1561 [00:02<00:02, 307.80it/s]
# Extracting Features:  59%|█████████████▌         | 923/1561 [00:02<00:02, 309.55it/s]

# %% [markdown]
# # 6.2 데이터 결합

# %%
# 리스트를 배열로 변환
if X_list_merge:
    X_raw_merge = np.vstack(X_list_merge)
    logger.info(f"전체 MergeData 특성 데이터 크기: {X_raw_merge.shape}")
else:
    X_raw_merge = np.array([])
    logger.warning("MergeData.csv 데이터가 비어있습니다.")

# %% [markdown]
# # 7. 레이블이 있는 데이터와 없는 데이터 결합
# ***
# ## 7.1 데이터 결합

# %%
# MHEALTH 데이터의 레이블은 그대로 유지
if X_raw_merge.size > 0:
    X_total = np.vstack((X_features_mhealth, X_raw_merge))
    # 레이블은 MHEALTH 데이터의 레이블과 MergeData의 레이블(없는 부분)을 결합
    y_total = np.hstack((y_labels_mhealth, np.full(X_raw_merge.shape[0], -1)))  # 레이블이 없는 부분은 -1로 표시
else:
    X_total = X_features_mhealth
    y_total = y_labels_mhealth

logger.info(f"결합된 데이터 크기: {X_total.shape}")
logger.info(f"결합된 레이블 크기: {y_total.shape}")

# %% [markdown]
# ## 7.2 데이터 증강 및 스케일링

# %%
logger.info("Applying data augmentation to labeled data...")
# 레이블이 있는 데이터에 대해서만 데이터 증강 적용
X_augmented, y_augmented = augment_data(X_features_mhealth, y_labels_mhealth)

# 원본 MHEALTH 데이터와 증강된 데이터 결합
X_mhealth_combined = np.vstack((X_features_mhealth, X_augmented))
y_mhealth_combined = np.hstack((y_labels_mhealth, y_augmented))

logger.info(f"증강된 MHEALTH 데이터 크기: {X_mhealth_combined.shape}")
logger.info(f"증강된 MHEALTH 레이블 크기: {y_mhealth_combined.shape}")

# 전체 데이터 결합 (MHEALTH 데이터와 MergeData 데이터)
if X_raw_merge.size > 0:
    X_total = np.vstack((X_mhealth_combined, X_raw_merge))
    y_total = np.hstack((y_mhealth_combined, np.full(X_raw_merge.shape[0], -1)))  # 레이블이 없는 부분은 -1로 표시
else:
    X_total = X_mhealth_combined
    y_total = y_mhealth_combined

logger.info(f"결합된 데이터 크기: {X_total.shape}")
logger.info(f"결합된 레이블 크기: {y_total.shape}")

# 스케일링
logger.info("Scaling the data...")
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_total)

# 스케일러 저장
joblib.dump(scaler, './scaler/scaler_total.pkl')
logger.info("스케일러를 'scaler_total.pkl'로 저장했습니다.")

# %% [markdown]
# # 8. 데이터셋 분할 및 시퀀스 생성
# ***
# ## 8.1 레이블이 있는 데이터와 없는 데이터 분리

# %%
logger.info("Separating labeled and unlabeled data...")
# 레이블이 있는 데이터만 분리
X_labeled = X_scaled[y_total != -1]
y_labeled = y_total[y_total != -1].astype(int)

# 레이블이 없는 데이터만 분리
X_unlabeled = X_scaled[y_total == -1]

logger.info(f"레이블이 있는 데이터 크기: {X_labeled.shape}")
logger.info(f"레이블이 없는 데이터 크기: {X_unlabeled.shape}")

# %% [markdown]
# ## 8.2 학습 및 검증 데이터 분할

# %%
logger.info("Splitting labeled data into training and validation sets...")
# 레이블이 있는 데이터셋 분할
X_train, X_val, y_train, y_val = train_test_split(
    X_labeled,
    y_labeled,
    test_size=0.2,
    random_state=42,
    stratify=y_labeled
)

logger.info(f"학습 데이터 크기: {X_train.shape}")
logger.info(f"검증 데이터 크기: {X_val.shape}")

# %% [markdown]
# ## 8.3 시퀀스 생성

# %%
# 시퀀스 길이 설정
seq_len = 10

def create_sequences(features, labels, seq_len):
    """
    시퀀스 데이터를 생성합니다.

    Parameters:
        features (numpy array): 입력 특성 데이터.
        labels (numpy array): 레이블 데이터.
        seq_len (int): 시퀀스 길이.

    Returns:
        tuple: 시퀀스 데이터와 시퀀스 레이블.
    """
    
    sequences = []
    sequence_labels = []
    
    for i in range(len(features) - seq_len + 1):
        seq = features[i:i+seq_len]
        label = labels[i + seq_len - 1]  # 마지막 윈도우의 레이블을 시퀀스의 레이블로 사용
        sequences.append(seq)
        sequence_labels.append(label)
    
    return np.array(sequences), np.array(sequence_labels)

logger.info("Creating sequences for training data...")
# 학습 데이터에 시퀀스 생성
X_train_seq, y_train_seq = create_sequences(X_train, y_train, seq_len)
logger.info(f"학습 시퀀스 데이터 크기: {X_train_seq.shape}")
logger.info(f"학습 시퀀스 레이블 크기: {y_train_seq.shape}")

logger.info("Creating sequences for validation data...")
# 검증 데이터에 시퀀스 생성
X_val_seq, y_val_seq = create_sequences(X_val, y_val, seq_len)
logger.info(f"검증 시퀀스 데이터 크기: {X_val_seq.shape}")
logger.info(f"검증 시퀀스 레이블 크기: {y_val_seq.shape}")

# %% [markdown]
# # 9. 데이터셋 및 데이터로더 생성

# %%
class ActivityDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)
        
    def __len__(self):
        return len(self.y)
        
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

logger.info("Creating Dataset and DataLoader...")
# 데이터셋 생성
train_dataset = ActivityDataset(X_train_seq, y_train_seq)
val_dataset = ActivityDataset(X_val_seq, y_val_seq)

# 데이터로더 생성
batch_size = 64
train_loader = DataLoader(train_dataset,
                          batch_size=batch_size,
                          shuffle=True,
                          num_workers=0,  # Jupyter Notebook 환경에서는 0으로 설정
                          pin_memory=True)
val_loader = DataLoader(val_dataset,
                        batch_size=batch_size,
                        shuffle=False,
                        num_workers=0,  # Jupyter Notebook 환경에서는 0으로 설정
                        pin_memory=True)

logger.info("Dataset and DataLoader 생성 완료.")

# %% [markdown]
# # 10. CNN-LSTM 모델 정의

# %%
class CNNLSTMModel(nn.Module):
    def __init__(self, num_features, num_classes, dropout):
        super(CNNLSTMModel, self).__init__()
        self.num_features = num_features
        
        # Convolutional Layers
        self.conv1 = nn.Conv1d(in_channels=num_features,
                               out_channels=64,
                               kernel_size=3,
                               padding=1)
        self.bn1 = nn.BatchNorm1d(64)
        self.conv2 = nn.Conv1d(in_channels=64,
                               out_channels=128,
                               kernel_size=3,
                               padding=1)
        self.bn2 = nn.BatchNorm1d(128)
        self.dropout_conv = nn.Dropout(dropout)
        self.pool = nn.MaxPool1d(kernel_size=2)
        
        # LSTM Layer
        self.lstm = nn.LSTM(input_size=128,
                            hidden_size=256,
                            num_layers=2,
                            batch_first=True,
                            dropout=dropout)
        
        # Fully Connected Layer
        self.fc = nn.Linear(256, num_classes)

    def forward(self, x):
        # x shape: (batch_size, seq_len, num_features)
        x = x.permute(0, 2, 1)  # (batch_size, num_features, seq_len)
        
        # Convolutional Layers
        x = torch.relu(self.bn1(self.conv1(x)))  # (batch_size, 64, seq_len)
        x = torch.relu(self.bn2(self.conv2(x)))  # (batch_size, 128, seq_len)
        x = self.pool(x)                        # (batch_size, 128, seq_len/2)
        x = self.dropout_conv(x)
        x = x.permute(0, 2, 1)                  # (batch_size, seq_len/2, 128)
        
        # LSTM Layer
        x, _ = self.lstm(x)                     # (batch_size, seq_len/2, 256)
        x = x[:, -1, :]                         # (batch_size, 256)
        
        # Fully Connected Layer
        x = self.fc(x)                          # (batch_size, num_classes)
        return x

# 모델 초기화
num_features = X_train_seq.shape[2]  # num_features는 특성 수 (24)
num_classes = len(np.unique(y_train_seq))
dropout = 0.5

model = CNNLSTMModel(num_features, 
                     num_classes,
                     dropout)
model.to(device)

logger.info("CNN-LSTM 모델 구조:")
logger.info(model)

# %% [markdown]
# # 11. 하이퍼파라미터 튜닝
# ***
# ## 11.1 Objective 함수 정의

# %%
def objective(trial):
    """
    Optuna의 objective 함수 정의.

    Parameters:
        trial (optuna.trial.Trial): Optuna trial 객체.

    Returns:
        float: 검증 손실.
    """
    
    # 하이퍼파라미터 제안
    dropout = trial.suggest_float('dropout', 0.2, 0.5)
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-4, 1e-2)
    hidden_size = trial.suggest_int('hidden_size', 128, 256)
    num_layers = trial.suggest_int('num_layers', 1, 3)

    # 모델 초기화
    model = CNNLSTMModel(num_features, num_classes, dropout)
    model.lstm.hidden_size = hidden_size
    model.lstm.num_layers = num_layers
    model.to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    # 학습 설정
    num_epochs = 10
    best_val_loss = float('inf')
    patience = 3
    counter = 0

    for epoch in range(num_epochs):
        # 학습 모드
        model.train()
        total_loss = 0
        total_correct = 0

        for X_batch, y_batch in train_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
            
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()

            total_loss += loss.item() * X_batch.size(0)
            _, preds = torch.max(outputs, 1)
            total_correct += (preds == y_batch).sum().item()

        train_loss = total_loss / len(train_dataset)
        train_acc = total_correct / len(train_dataset)

        # 검증 모드
        model.eval()
        total_loss = 0
        total_correct = 0

        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch = X_batch.to(device)
                y_batch = y_batch.to(device)
                
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)
                
                total_loss += loss.item() * X_batch.size(0)
                _, preds = torch.max(outputs, 1)
                total_correct += (preds == y_batch).sum().item()

        val_loss = total_loss / len(val_dataset)
        val_acc = total_correct / len(val_dataset)

        # 검증 손실이 개선되었는지 확인
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                break

        # Optuna에 보고
        trial.report(val_loss, epoch)

        # 조기 종료 판단
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()

    return best_val_loss  # 검증 손실을 최소화

# %% [markdown]
# ## 11.2 스터디 객체 생성 및 최적화 수행

# %%
logger.info("Starting hyperparameter tuning with Optuna...")
# 스터디 객체 생성
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=20, timeout=None)

# 최적의 하이퍼파라미터 출력
logger.info("Best hyperparameters: ")
for key, value in study.best_params.items():
    logger.info(f"  {key}: {value}")

# %% [markdown]
# # 12. 모델 학습

# %%
# 최적의 하이퍼파라미터로 모델 초기화
best_dropout = study.best_params['dropout']
best_learning_rate = study.best_params['learning_rate']
best_hidden_size = study.best_params['hidden_size']
best_num_layers = study.best_params['num_layers']

logger.info(f"Initializing model with best hyperparameters: dropout={best_dropout}, learning_rate={best_learning_rate}, hidden_size={best_hidden_size}, num_layers={best_num_layers}")
model = CNNLSTMModel(num_features,
                     num_classes,
                     best_dropout)
model.lstm.hidden_size = best_hidden_size
model.lstm.num_layers = best_num_layers
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=best_learning_rate)

# 학습 설정
num_epochs = 200
patience = 5
best_val_loss = float('inf')
counter = 0

# 손실과 정확도를 저장할 리스트 초기화
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

logger.info("Starting training with optimized hyperparameters...")
for epoch in range(num_epochs):
    # 학습 모드
    model.train()
    total_loss = 0
    total_correct = 0
    
    # tqdm을 사용하여 배치별 진행 상황 시각화
    for X_batch, y_batch in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} - Training", leave=False):
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)
        
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item() * X_batch.size(0)
        _, preds = torch.max(outputs, 1)
        total_correct += (preds == y_batch).sum().item()
    
    train_loss = total_loss / len(train_dataset)
    train_acc = total_correct / len(train_dataset)
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)
    
    # 검증 모드
    model.eval()
    total_loss = 0
    total_correct = 0
    
    with torch.no_grad():
        for X_batch, y_batch in tqdm(val_loader, desc=f"Epoch {epoch+1}/{num_epochs} - Validation", leave=False):
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
            
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            
            total_loss += loss.item() * X_batch.size(0)
            _, preds = torch.max(outputs, 1)
            total_correct += (preds == y_batch).sum().item()
    
    val_loss = total_loss / len(val_dataset)
    val_acc = total_correct / len(val_dataset)
    val_losses.append(val_loss)
    val_accuracies.append(val_acc)
    
    # 검증 손실이 개선되었는지 확인하고 모델 저장
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), 'best_model.pth')
        counter = 0
        logger.info(f"Epoch {epoch+1}: 검증 손실이 개선되어 모델을 저장했습니다. Val Loss: {val_loss:.4f}, Val Acc: {val_acc*100:.2f}%")
    else:
        counter += 1
        logger.info(f"Epoch {epoch+1}: 검증 손실이 개선되지 않았습니다. Val Loss: {val_loss:.4f}, Val Acc: {val_acc*100:.2f}%")
        if counter >= patience:
            logger.info("조기 종료 조건에 도달하여 학습을 종료합니다.")
            break
    
    # 에포크 결과 출력
    logger.info(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, "
                f"Train Acc: {train_acc*100:.2f}%, Val Loss: {val_loss:.4f}, "
                f"Val Acc: {val_acc*100:.2f}%")

# %% [markdown]
# # 13. 모델 평가 및 시각화
# ***
# ## 13.1. 학습 및 검증 손실, 정확도 곡선 그리기

# %%
logger.info("Plotting loss and accuracy curves...")

plt.figure(figsize=(12, 5))

# 손실 곡선 그리기
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss', color='blue')
plt.plot(val_losses, label='Validation Loss', color='orange')
plt.title('Loss Curve')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# 정확도 곡선 그리기
plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy', color='blue')
plt.plot(val_accuracies, label='Validation Accuracy', color='orange')
plt.title('Accuracy Curve')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# - 손실 곡선은 모델의 학습 및 검증 손실을 보여주며, 오버피팅 여부를 판단하는 데 도움이 됩니다.
# - 정확도 곡선은 모델의 학습 및 검증 정확도를 보여줍니다.

# %% [markdown]
# ## 13.2. 혼동 행렬 시각화 및 분류 보고서 출력

# %%
logger.info("Generating confusion matrix and classification report...")

# 전체 검증 데이터에 대한 예측 수행
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for X_batch, y_batch in tqdm(val_loader, desc="Generating Predictions"):
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)
        
        outputs = model(X_batch)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(y_batch.cpu().numpy())

# 혼동 행렬 계산
cm = confusion_matrix(all_labels, all_preds)

# 클래스 이름 정의 (레이블 인덱스와 매칭)
class_names = ['WALKING',
               'WALKING_UPSTAIRS',
               'WALKING_DOWNSTAIRS',
               'SITTING',
               'STANDING',
               'LAYING']

# 혼동 행렬 시각화
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Confusion Matrix')
plt.show()

# 분류 보고서 출력
logger.info("Classification Report:")
report = classification_report(all_labels, all_preds, target_names=class_names)
logger.info(f"\n{report}")
print("Classification Report:")
print(report)

# %% [markdown]
# # 14. MergeData.csv 데이터에 대한 예측 및 레이블 추가
# ***
# ## 14.1. MergeData.csv 데이터 예측

# %%
# 저장된 모델 및 스케일러 로드
logger.info("Loading the best model and scaler for prediction...")
model = CNNLSTMModel(num_features,
                     num_classes,
                     best_dropout)
model.lstm.hidden_size = best_hidden_size
model.lstm.num_layers = best_num_layers
model.load_state_dict(torch.load('./model/best_model.pth'))
model.to(device)
model.eval()
logger.info("모델과 스케일러 로드 완료.")

scaler = joblib.load('./scaler/scaler_total.pkl')
pca = joblib.load('scaler_total.pkl')  # 이미 스케일링된 데이터이므로 PCA는 필요 없습니다.

# 클래스 이름 정의
class_names = ['WALKING',
               'WALKING_UPSTAIRS',
               'WALKING_DOWNSTAIRS',
               'SITTING',
               'STANDING',
               'LAYING']

# 예측 결과를 저장할 리스트
predictions = []
indices = []

logger.info("Starting prediction on MergeData.csv...")
# MergeData.csv를 청크 단위로 로드하여 예측 수행
reader = pd.read_csv(merge_data_path,
                     chunksize=chunk_size,
                     names=column_names,
                     header=0)

for chunk in tqdm(reader, desc="Predicting MergeData"):
    # 자이로스코프 데이터 추출 (X, Y, Z 컬럼)
    gyro_data = chunk[['X', 'Y', 'Z']].values

    if gyro_data.shape[0] < window_size:
        continue  # 데이터 길이가 윈도우 크기보다 작으면 건너뜀

    # 슬라이딩 윈도우 적용
    windows = sliding_window(gyro_data, window_size, step_size)

    if windows.size == 0:
        continue

    # 특성 추출
    features = extract_features(windows)

    # 데이터 증강 적용 (레이블이 없으므로 증강된 데이터의 레이블은 -1로 설정)
    # 여기서는 증강된 데이터를 사용하지 않고 원본 데이터만 예측합니다.

    # 시퀀스 생성
    X_seq, _ = create_sequences(features, np.zeros(len(features)), seq_len)

    if X_seq.size == 0:
        continue

    # 모델 입력을 위한 텐서 변환
    X_tensor = torch.tensor(X_seq, dtype=torch.float32).to(device)

    # 모델 예측
    with torch.no_grad():
        outputs = model(X_tensor)
        _, preds = torch.max(outputs, 1)
        predictions.extend(preds.cpu().numpy())

        # 각 시퀀스의 시작 인덱스를 저장
        window_starts = np.arange(0, len(features) - seq_len + 1)
        indices.extend(chunk.index.values[window_starts])

logger.info("Prediction on MergeData.csv 완료.")

# %% [markdown]
# ## 14.2. 예측된 레이블 추가 및 저장

# %%
logger.info("Adding predicted labels to MergeData and saving the results...")

# 예측된 활동 이름으로 변환
predicted_activities = [class_names[pred] for pred in predictions]

# 결과를 DataFrame으로 저장
result_df = pd.DataFrame({
    'Index': indices,
    'Predicted Activity': predicted_activities
})

# 원본 MergeData에서 해당 인덱스의 데이터 추출
merge_data_full = pd.read_csv(merge_data_path, names=column_names, header=0)
predicted_data = merge_data_full.iloc[indices].copy()
predicted_data['Activity'] = predicted_activities

# 결과를 CSV 파일로 저장
predicted_data.to_csv('MergeData_Prediction.csv', index=False)
logger.info("예측 결과를 'MergeData_Prediction.csv'에 저장했습니다.")

# %% [markdown]
# ## 14.3. 예측 결과 시각화

# %%
logger.info("Visualizing the distribution of predicted activities...")

# 예측된 활동 레이블의 분포 시각화
activity_counts = pd.Series(predicted_activities).value_counts()
plt.figure(figsize=(8, 6))
sns.barplot(x=activity_counts.index, y=activity_counts.values, palette='viridis')
plt.title('Predicted Activity Distribution')
plt.xlabel('Activity')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 15. 마무리

# %%
logger.info("모델 학습 및 예측 과정이 완료되었습니다.")
logger.info("모델과 스케일러, PCA 모델을 저장합니다.")

# 최종 모델 저장 (이미 최적의 모델은 'best_model.pth'로 저장됨)
torch.save(model.state_dict(), 'final_model.pth')
logger.info("최종 모델을 'final_model.pth'로 저장했습니다.")

# 스케일러 저장 (이미 저장됨)
# joblib.dump(scaler, 'scaler_total.pkl')
# logger.info("스케일러를 'scaler_total.pkl'로 저장했습니다.")

logger.info("전체 프로세스가 성공적으로 완료되었습니다.")
